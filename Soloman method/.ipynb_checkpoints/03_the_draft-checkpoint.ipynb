# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pulp 
import glob
import os

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100)

# %% [markdown]
# # Rules

# %% [markdown]
# ## Positions
# To join the game select a fantasy football squad of 15 players, consisting of:
#
# - 2 Goalkeepers
# - 5 Defenders
# - 5 Midfielders
# - 3 Forwards

# %% [markdown]
# ## Budget
# The total value of your initial squad must not exceed £100 million.

# %% [markdown]
# ## Players Per Team
# You can select up to 3 players from a single Premier League team.

# %% [markdown]
# # Pull data

# %%
list_of_files = glob.glob('Data/Forecasts/*')
latest_file = max(list_of_files, key=os.path.getctime)
print('Opening ', latest_file)

input_df = pd.read_csv(latest_file).sort_values(['name','FIX_Fixture_date'])

games_played = input_df.loc[input_df['forecast'] == 0]
last_four_games = input_df.loc[input_df['forecast'] == 0].groupby('name').tail(4)

next_four_games = input_df.loc[input_df['forecast'] != 0].groupby('name').head(4)
next_game = input_df.loc[input_df['forecast'] != 0].groupby('name').head(1)
# Out:
# Opening  Data/Forecasts/2020-06-25 16:29:54.942182.csv

# %%
data = input_df.groupby(['name','FIX_season']).agg({'position' : 'mean',
                                                    'cost_today' : 'mean'}).reset_index()

data = pd.concat([data,pd.get_dummies(data['position'])], axis = 1)


data = data.rename(columns = {1.0 : 'keeper'
                             ,2.0 : 'defender'
                             ,3.0 : 'mid-field'
                             ,4.0 : 'striker'})

data = data.set_index('name')


# Make columns for teams
data['Current_team'] = games_played.groupby('name')['FIX_team'].last()
data = pd.concat([data,pd.get_dummies(data['Current_team'], prefix = "TEAM_TRANSFORM")], axis = 1)

# Data from games already played
data['TSS_games_played'] = games_played.groupby('name')['FIX_Fixture_date'].count()
data['TSS_average_points_per_game'] = games_played.groupby('name')['total_points'].mean()
data['TSS_total_points_this_season'] = games_played.groupby('name')['total_points'].sum()
data['TSS_average_minutes_per_game'] = games_played.groupby('name')['minutes'].mean()
data['TSS_rank'] = data['TSS_total_points_this_season'].rank(ascending = False)

# Data from recent games
data['L4W_games_played'] = last_four_games.groupby('name')['FIX_Fixture_date'].count()
data['L4W_average_points_per_game'] = last_four_games.groupby('name')['total_points'].mean()
data['L4W_total_points_this_season'] = last_four_games.groupby('name')['total_points'].sum()
data['L4W_average_minutes_per_game'] = last_four_games.groupby('name')['minutes'].mean()


# Points forecasts
data['forecast_points_for_season_sum'] = input_df.groupby('name')['forecast_points'].sum()
data['forecast_points_for_season_mean'] = input_df.groupby('name')['forecast_points'].mean()

data['forecast_points_N4G_sum'] = next_four_games.groupby('name')['forecast_points'].sum()
data['forecast_points_N4G_mean'] = next_four_games.groupby('name')['forecast_points'].mean()

data['forecast_points_next_game'] = next_game.groupby('name')['forecast_points'].mean()

data.head()
# Out:
#                 FIX_season  position  cost_today  keeper  defender  mid-field  striker  \
# name
# Aaron_Connolly     2019-20       4.0        42.0       0         0          0        1
# Aaron_Cresswell    2019-20       2.0        45.0       0         1          0        0
# Aaron_Lennon       2019-20       3.0        46.0       0         0          1        0
# Aaron_Mooy         2019-20       3.0        48.0       0         0          1        0
# Aaron_Ramsdale     2019-20       1.0        45.0       1         0          0        0
#
#                 Current_team  TEAM_TRANSFORM_Arsenal  TEAM_TRANSFORM_Aston Villa  \
# name
# Aaron_Connolly      Brighton                       0                           0
# Aaron_Cresswell     West Ham                       0                           0
# Aaron_Lennon         Burnley                       0                           0
# Aaron_Mooy          Brighton                       0                           0
# Aaron_Ramsdale   Bournemouth                       0                           0
#
#                  TEAM_TRANSFORM_Bournemouth  TEAM_TRANSFORM_Brighton  TEAM_TRANSFORM_Burnley  \
# name
# Aaron_Connolly                            0                        1                       0
# Aaron_Cresswell                           0                        0                       0
# Aaron_Lennon                              0                        0                       1
# Aaron_Mooy                                0                        1                       0
# Aaron_Ramsdale                            1                        0                       0
#
#                  TEAM_TRANSFORM_Chelsea  TEAM_TRANSFORM_Crystal Palace  TEAM_TRANSFORM_Everton  \
# name
# Aaron_Connolly                        0                              0                       0
# Aaron_Cresswell                       0                              0                       0
# Aaron_Lennon                          0                              0                       0
# Aaron_Mooy                            0                              0                       0
# Aaron_Ramsdale                        0                              0                       0
#
#                  TEAM_TRANSFORM_Leicester  TEAM_TRANSFORM_Liverpool  TEAM_TRANSFORM_Man City  \
# name
# Aaron_Connolly                          0                         0                        0
# Aaron_Cresswell                         0                         0                        0
# Aaron_Lennon                            0                         0                        0
# Aaron_Mooy                              0                         0                        0
# Aaron_Ramsdale                          0                         0                        0
#
#                  TEAM_TRANSFORM_Man Utd  TEAM_TRANSFORM_Newcastle  TEAM_TRANSFORM_Norwich  \
# name
# Aaron_Connolly                        0                         0                       0
# Aaron_Cresswell                       0                         0                       0
# Aaron_Lennon                          0                         0                       0
# Aaron_Mooy                            0                         0                       0
# Aaron_Ramsdale                        0                         0                       0
#
#                  TEAM_TRANSFORM_Sheffield Utd  TEAM_TRANSFORM_Southampton  TEAM_TRANSFORM_Spurs  \
# name
# Aaron_Connolly                              0                           0                     0
# Aaron_Cresswell                             0                           0                     0
# Aaron_Lennon                                0                           0                     0
# Aaron_Mooy                                  0                           0                     0
# Aaron_Ramsdale                              0                           0                     0
#
#                  TEAM_TRANSFORM_Watford  TEAM_TRANSFORM_West Ham  TEAM_TRANSFORM_Wolves  \
# name
# Aaron_Connolly                        0                        0                      0
# Aaron_Cresswell                       0                        1                      0
# Aaron_Lennon                          0                        0                      0
# Aaron_Mooy                            0                        0                      0
# Aaron_Ramsdale                        0                        0                      0
#
#                  TSS_games_played  TSS_average_points_per_game  TSS_total_points_this_season  \
# name
# Aaron_Connolly               26.0                     1.692308                          44.0
# Aaron_Cresswell              29.0                     2.206897                          64.0
# Aaron_Lennon                 29.0                     0.482759                          14.0
# Aaron_Mooy                   29.0                     2.206897                          64.0
# Aaron_Ramsdale               29.0                     3.275862                          95.0
#
#                  TSS_average_minutes_per_game  TSS_rank  L4W_games_played  \
# name
# Aaron_Connolly                      31.615385     234.5               4.0
# Aaron_Cresswell                     69.758621     151.0               4.0
# Aaron_Lennon                        16.517241     377.0               4.0
# Aaron_Mooy                          58.482759     151.0               4.0
# Aaron_Ramsdale                      86.896552      63.5               4.0
#
#                  L4W_average_points_per_game  L4W_total_points_this_season  \
# name
# Aaron_Connolly                          1.25                           5.0
# Aaron_Cresswell                         1.25                           5.0
# Aaron_Lennon                            0.25                           1.0
# Aaron_Mooy                              1.75                           7.0
# Aaron_Ramsdale                          2.00                           8.0
#
#                  L4W_average_minutes_per_game  forecast_points_for_season_sum  \
# name
# Aaron_Connolly                           8.50                        6.515473
# Aaron_Cresswell                         90.00                       20.417486
# Aaron_Lennon                             2.25                        2.372625
# Aaron_Mooy                              78.25                       18.293724
# Aaron_Ramsdale                          90.00                       26.698627
#
#                  forecast_points_for_season_mean  forecast_points_N4G_sum  \
# name
# Aaron_Connolly                          0.814434                 3.395472
# Aaron_Cresswell                         2.552186                10.126764
# Aaron_Lennon                            0.296578                 1.124454
# Aaron_Mooy                              2.286716                 9.085655
# Aaron_Ramsdale                          3.337328                13.116937
#
#                  forecast_points_N4G_mean  forecast_points_next_game
# name
# Aaron_Connolly                   0.848868                   0.946353
# Aaron_Cresswell                  2.531691                   2.073563
# Aaron_Lennon                     0.281114                   0.311267
# Aaron_Mooy                       2.271414                   2.171917
# Aaron_Ramsdale                   3.279234                   2.952443

# %% [markdown]
# # Exclusions

# %%
data['Exclude'] = 0
data.loc[data.index == 'Wilfried_Zaha'] = 1

data.loc[data['Exclude'] == 1]
# Out:
#               FIX_season  position  cost_today  keeper  defender  mid-field  striker Current_team  \
# name
# Wilfried_Zaha          1       1.0         1.0       1         1          1        1            1
#
#                TEAM_TRANSFORM_Arsenal  TEAM_TRANSFORM_Aston Villa  TEAM_TRANSFORM_Bournemouth  \
# name
# Wilfried_Zaha                       1                           1                           1
#
#                TEAM_TRANSFORM_Brighton  TEAM_TRANSFORM_Burnley  TEAM_TRANSFORM_Chelsea  \
# name
# Wilfried_Zaha                        1                       1                       1
#
#                TEAM_TRANSFORM_Crystal Palace  TEAM_TRANSFORM_Everton  TEAM_TRANSFORM_Leicester  \
# name
# Wilfried_Zaha                              1                       1                         1
#
#                TEAM_TRANSFORM_Liverpool  TEAM_TRANSFORM_Man City  TEAM_TRANSFORM_Man Utd  \
# name
# Wilfried_Zaha                         1                        1                       1
#
#                TEAM_TRANSFORM_Newcastle  TEAM_TRANSFORM_Norwich  TEAM_TRANSFORM_Sheffield Utd  \
# name
# Wilfried_Zaha                         1                       1                             1
#
#                TEAM_TRANSFORM_Southampton  TEAM_TRANSFORM_Spurs  TEAM_TRANSFORM_Watford  \
# name
# Wilfried_Zaha                           1                     1                       1
#
#                TEAM_TRANSFORM_West Ham  TEAM_TRANSFORM_Wolves  TSS_games_played  \
# name
# Wilfried_Zaha                        1                      1               1.0
#
#                TSS_average_points_per_game  TSS_total_points_this_season  \
# name
# Wilfried_Zaha                          1.0                           1.0
#
#                TSS_average_minutes_per_game  TSS_rank  L4W_games_played  \
# name
# Wilfried_Zaha                           1.0       1.0               1.0
#
#                L4W_average_points_per_game  L4W_total_points_this_season  \
# name
# Wilfried_Zaha                          1.0                           1.0
#
#                L4W_average_minutes_per_game  forecast_points_for_season_sum  \
# name
# Wilfried_Zaha                           1.0                             1.0
#
#                forecast_points_for_season_mean  forecast_points_N4G_sum  forecast_points_N4G_mean  \
# name
# Wilfried_Zaha                              1.0                      1.0                       1.0
#
#                forecast_points_next_game  Exclude
# name
# Wilfried_Zaha                        1.0        1

# %% [markdown]
# # Linear optimiser

# %%
def the_draft(data, objective_func):
    
    the_draft = pulp.LpProblem("the_draft", pulp.LpMaximize)
    
    # Decision variable
    player_selected = pulp.LpVariable.dicts("selected",
                                     (name for name in data.index),
                                     cat='Binary')
    
    # Objective function 
    the_draft += pulp.lpSum([data.loc[name, objective_func] * player_selected[name]  for name in data.index])
    
    # Constraints
    # 2 GK
    the_draft += pulp.lpSum([data.loc[name, 'keeper'] * player_selected[name]  for name in data.index]) == 2

    # 5 DEF
    the_draft += pulp.lpSum([data.loc[name, 'defender'] * player_selected[name]  for name in data.index]) == 5

    # 5 MID
    the_draft += pulp.lpSum([data.loc[name, 'mid-field'] * player_selected[name]  for name in data.index]) == 5

    # 3 FOR
    the_draft += pulp.lpSum([data.loc[name, 'striker'] * player_selected[name]  for name in data.index]) == 3

    # Total cost < £100M
    the_draft += pulp.lpSum([data.loc[name, 'cost_today'] * player_selected[name]  for name in data.index]) <= 1000

    # No more than 3 from each team
    for col in [c for c in data.columns if str.startswith(c, 'TEAM_TRANSFORM')]:
        the_draft += pulp.lpSum([data.loc[name, col] * player_selected[name]  for name in data.index]) <=3
        

    # No one who's been excluded (above)
    the_draft += pulp.lpSum([data.loc[name, 'Exclude'] * player_selected[name]  for name in data.index]) == 0 
    
    the_draft.solve()
    print("Optimiser status: ", pulp.LpStatus[the_draft.status])
    
    output = []
    
    for name in data.index:
        var_output ={'Name': name,
                    'Player_selected': player_selected[name].varValue}
        output.append(var_output)
        
    output_df = pd.DataFrame.from_records(output).set_index(['Name'])

    return output_df

# %%
optimiser_selection = the_draft(data, 'forecast_points_for_season_sum')
# Out:
# Optimiser status:  Optimal

# %%
data['Player_selected'] = optimiser_selection['Player_selected']

# %% [markdown]
# # The team

# %%
team = data.loc[data['Player_selected'] == True]
team.sort_values('forecast_points_next_game', ascending = False)
# Out:
#                                FIX_season  position  cost_today  keeper  defender  mid-field  \
# name
# Sadio_ManÃ©                       2019-20       3.0       125.0       0         0          1
# Trent_Alexander-Arnold            2019-20       2.0        78.0       0         1          0
# RaÃºl_JimÃ©nez                    2019-20       4.0        81.0       0         0          0
# Danny_Ings                        2019-20       4.0        71.0       0         0          0
# Virgil_van Dijk                   2019-20       2.0        65.0       0         1          0
# Rui Pedro_dos Santos PatrÃ­cio    2019-20       1.0        52.0       1         0          0
# Matt_Doherty                      2019-20       2.0        63.0       0         1          0
# Miguel_AlmirÃ³n                   2019-20       3.0        58.0       0         0          1
# Steven_Bergwijn                   2019-20       3.0        74.0       0         0          1
# James_Ward-Prowse                 2019-20       3.0        57.0       0         0          1
# Patrick_van Aanholt               2019-20       2.0        56.0       0         1          0
# Dean_Henderson                    2019-20       1.0        53.0       1         0          0
# George_Baldock                    2019-20       2.0        51.0       0         1          0
# Jordan_Ayew                       2019-20       4.0        52.0       0         0          0
# Abdoulaye_DoucourÃ©               2019-20       3.0        56.0       0         0          1
#
# Dean_Henderson                                     86.896552      11.5               4.0
# George_Baldock                                     90.000000      24.0               4.0
# Jordan_Ayew                                        83.034483      39.0               4.0
# Abdoulaye_DoucourÃ©                                83.758621      58.0               4.0
#
#                                 L4W_average_points_per_game  L4W_total_points_this_season  \
# name
# Sadio_ManÃ©                                            6.50                          26.0
# Trent_Alexander-Arnold                                 5.00                          20.0
# RaÃºl_JimÃ©nez                                         5.50                          22.0
# Danny_Ings                                             4.00                          16.0
# Virgil_van Dijk                                        3.50                          14.0
# Rui Pedro_dos Santos PatrÃ­cio                         5.25                          21.0
# Matt_Doherty                                          10.00                          40.0
# Miguel_AlmirÃ³n                                        3.25                          13.0
# Steven_Bergwijn                                        5.25                          21.0
# James_Ward-Prowse                                      3.25                          13.0
# Patrick_van Aanholt                                   10.25                          41.0
# Dean_Henderson                                         5.50                          22.0
# George_Baldock                                         3.75                          15.0
# Jordan_Ayew                                            5.75                          23.0
# Abdoulaye_DoucourÃ©                                    3.00                          12.0
#
#                                 L4W_average_minutes_per_game  forecast_points_for_season_sum  \
# name
# Sadio_ManÃ©                                            90.00                       44.536725
# Trent_Alexander-Arnold                                 90.00                       42.457766
# RaÃºl_JimÃ©nez                                         85.25                       40.775295
# Danny_Ings                                             71.25                       39.151966
# Virgil_van Dijk                                        90.00                       37.721387
# Rui Pedro_dos Santos PatrÃ­cio                         90.00                       36.238433
# Matt_Doherty                                           90.00                       35.659622
# Miguel_AlmirÃ³n                                        83.50                       33.562050
# Steven_Bergwijn                                        81.50                       35.887067
# James_Ward-Prowse                                      90.00                       31.161827
# Patrick_van Aanholt                                    90.00                       35.183380
# Dean_Henderson                                         90.00                       34.089347
# George_Baldock                                         90.00                       32.074522
# Jordan_Ayew                                            90.00                       32.532140
# Abdoulaye_DoucourÃ©                                    83.25                       31.495246
#
#                                 forecast_points_for_season_mean  forecast_points_N4G_sum  \
# name
# Sadio_ManÃ©                                            5.567091                22.220932
# Trent_Alexander-Arnold                                 5.307221                21.148233
# RaÃºl_JimÃ©nez                                         5.096912                20.225896
# Danny_Ings                                             4.893996                19.480394
# Virgil_van Dijk                                        4.715173                18.718200
# Rui Pedro_dos Santos PatrÃ­cio                         4.529804                18.043134
# Matt_Doherty                                           4.457453                17.584030
# Miguel_AlmirÃ³n                                        4.195256                16.803022
# Steven_Bergwijn                                        4.485883                17.494609
# James_Ward-Prowse                                      3.895228                15.502725
# Patrick_van Aanholt                                    4.397922                17.560548
# Dean_Henderson                                         4.261168                16.842047
# George_Baldock                                         4.009315                16.040877
# Jordan_Ayew                                            4.066517                16.400251
# Abdoulaye_DoucourÃ©                                    3.936906                15.655900
#
#                                 forecast_points_N4G_mean  forecast_points_next_game  Exclude  \
# name
# Sadio_ManÃ©                                     5.555233                   5.713264        0
# Trent_Alexander-Arnold                          5.287058                   5.537098        0
# RaÃºl_JimÃ©nez                                  5.056474                   5.335592        0
# Danny_Ings                                      4.870099                   5.283323        0
# Virgil_van Dijk                                 4.679550                   4.983258        0
# Rui Pedro_dos Santos PatrÃ­cio                  4.510784                   4.746474        0
# Matt_Doherty                                    4.396008                   4.732237        0
# Miguel_AlmirÃ³n                                 4.200755                   4.609133        0
# Steven_Bergwijn                                 4.373652                   4.372762        0
# James_Ward-Prowse                               3.875681                   4.239811        0
# Patrick_van Aanholt                             4.390137                   3.994094        0
# Dean_Henderson                                  4.210512                   3.886267        0
# George_Baldock                                  4.010219                   3.698006        0
# Jordan_Ayew                                     4.100063                   3.687376        0
# Abdoulaye_DoucourÃ©                             3.913975                   3.642172        0
#
#                                 Player_selected
# name
# Sadio_ManÃ©                                 1.0
# Trent_Alexander-Arnold                      1.0
# RaÃºl_JimÃ©nez                              1.0
# Danny_Ings                                  1.0
# Virgil_van Dijk                             1.0
# Rui Pedro_dos Santos PatrÃ­cio              1.0
# Matt_Doherty                                1.0
# Miguel_AlmirÃ³n                             1.0
# Steven_Bergwijn                             1.0
# James_Ward-Prowse                           1.0
# Patrick_van Aanholt                         1.0
# Dean_Henderson                              1.0
# George_Baldock                              1.0
# Jordan_Ayew                                 1.0
# Abdoulaye_DoucourÃ©                         1.0

# %%
team.agg({'cost_today':'sum',
          'keeper': 'sum',
          'defender': 'sum',
          'mid-field': 'sum',
          'striker': 'sum',
          'TSS_average_points_per_game' : 'sum',
          'TSS_average_minutes_per_game' : 'mean',
          'L4W_average_points_per_game' : 'sum',
          'L4W_average_minutes_per_game' : 'mean',
          'forecast_points_for_season_sum' : 'sum',
          'forecast_points_for_season_mean': 'sum',
          'forecast_points_N4G_sum' : 'sum',
          'forecast_points_N4G_mean' : 'sum',
          'forecast_points_next_game': 'sum'})
# Out:
# cost_today                         992.000000
# keeper                               2.000000
# defender                             5.000000
# mid-field                            5.000000
# striker                              3.000000
# TSS_average_points_per_game         65.151724
# TSS_average_minutes_per_game        82.266207
# L4W_average_points_per_game         79.750000
# L4W_average_minutes_per_game        86.983333
# forecast_points_for_season_sum     542.526772
# forecast_points_for_season_mean     67.815846
# forecast_points_N4G_sum            269.720798
# forecast_points_N4G_mean            67.430200
# forecast_points_next_game           68.460865
# dtype: float64

# %%
team['Current_team'].value_counts()
# Out:
# Wolves            3
# Liverpool         3
# Sheffield Utd     2
# Southampton       2
# Crystal Palace    2
# Spurs             1
# Newcastle         1
# Watford           1
# Name: Current_team, dtype: int64

# %%
games_played.groupby(['name'])['total_points'].sum().sort_values(ascending = False).head(15)
# Out:
# name
# Kevin_De Bruyne              186.0
# Sadio_ManÃ©                  177.0
# Mohamed_Salah                174.0
# Trent_Alexander-Arnold       168.0
# Jamie_Vardy                  167.0
# RaÃºl_JimÃ©nez               153.0
# Pierre-Emerick_Aubameyang    150.0
# Danny_Ings                   149.0
# Virgil_van Dijk              139.0
# Andrew_Robertson             135.0
# Dean_Henderson               133.0
# Richarlison_de Andrade       133.0
# Tammy_Abraham                131.0
# John_Lundstram               130.0
# Roberto_Firmino              127.0
# Name: total_points, dtype: float64

# %% [markdown]
# # Review previous predictions

# %%
x = pd.read_csv('Data/Forecasts/2020-06-25 14:56:46.881547.csv')

x.loc[x['name'] == 'Mohamed_Salah']['forecast_points'].sum()
