# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pulp 
import glob
import os
import Setup
# Out:
# /Users/calumthompson/Google Drive/Fantasy_football/Setup.py:10: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
data_path = Setup.github_address
season_folders = Setup.season_folders
season_names = Setup.season_names
this_season = Setup.this_season

# %% [markdown]
# # Rules

# %% [markdown]
# ## Positions
# To join the game select a fantasy football squad of 15 players, consisting of:
#
# - 2 Goalkeepers
# - 5 Defenders
# - 5 Midfielders
# - 3 Forwards

# %% [markdown]
# ## Budget
# The total value of your initial squad must not exceed £100 million.

# %% [markdown]
# ## Players Per Team
# You can select up to 3 players from a single Premier League team.

# %% [markdown]
# # Pull data

# %%
list_of_file_addresses = glob.glob('Data/Input_data/*')
latest_file_address = max(list_of_file_addresses, key=os.path.getctime)
print('Opening ', latest_file_address)

input_df = pd.read_csv(latest_file_address).sort_values(['second_name','first_name','FIX_Fixture_date'])

games_played = input_df.loc[input_df['forecast'] == 0]
last_four_games = input_df.loc[input_df['forecast'] == 0].groupby(['second_name','first_name']).tail(4)

next_four_games = input_df.loc[input_df['forecast'] != 0].groupby(['second_name','first_name']).head(4)
next_game = input_df.loc[input_df['forecast'] != 0].groupby(['second_name','first_name']).head(1)
# Out:
# Opening  Data/Input_data/2020-12-03.csv

# %%
data = input_df.groupby(['second_name','first_name','FIX_season']).agg({'position' : 'mean',
                                                    'cost_today' : 'mean'}).reset_index()

data = pd.concat([data,pd.get_dummies(data['position'])], axis = 1)


data = data.rename(columns = {1.0 : 'keeper'
                             ,2.0 : 'defender'
                             ,3.0 : 'mid-field'
                             ,4.0 : 'striker'})

data = data.set_index(['second_name','first_name'])


# Make columns for teams
data['Current_team'] = games_played.groupby(['second_name','first_name'])['FIX_team'].last()
data = pd.concat([data,pd.get_dummies(data['Current_team'], prefix = "TEAM_TRANSFORM")], axis = 1)

# Data from games already played
data['TSS_games_played'] = games_played.groupby(['second_name','first_name'])['FIX_Fixture_date'].count()
data['TSS_average_points_per_game'] = games_played.groupby(['second_name','first_name'])['total_points'].mean()
data['TSS_total_points_this_season'] = games_played.groupby(['second_name','first_name'])['total_points'].sum()
# data['TSS_average_minutes_per_game'] = games_played.groupby(['second_name','first_name'])['minutes'].mean()
data['TSS_rank'] = data['TSS_total_points_this_season'].rank(ascending = False)

# Data from recent games
data['L4W_games_played'] = last_four_games.groupby(['second_name','first_name'])['FIX_Fixture_date'].count()
data['L4W_average_points_per_game'] = last_four_games.groupby(['second_name','first_name'])['total_points'].mean()
data['L4W_total_points'] = last_four_games.groupby(['second_name','first_name'])['total_points'].sum()
# data['L4W_average_minutes_per_game'] = last_four_games.groupby(['second_name','first_name'])['minutes'].mean()


# Points forecasts
data['forecast_points_for_season_sum'] = input_df.groupby(['second_name','first_name'])['forecast_points'].sum()
data['forecast_points_for_season_mean'] = input_df.groupby(['second_name','first_name'])['forecast_points'].mean()

data['forecast_points_N4G_sum'] = next_four_games.groupby(['second_name','first_name'])['forecast_points'].sum()
data['forecast_points_N4G_mean'] = next_four_games.groupby(['second_name','first_name'])['forecast_points'].mean()

data['forecast_points_next_game'] = next_game.groupby(['second_name','first_name'
                                                      ])['forecast_points'].mean()

data = data.loc[data['FIX_season'] == this_season]

data.head()
# Out:
#                            FIX_season  position  cost_today  keeper  defender  mid-field  striker  \
# second_name     first_name
# Aarons          Rolando     2020-21    3.0       48.0        0       0         1          0
# Abraham         Tammy       2020-21    4.0       72.0        0       0         0          1
# Adams           Che         2020-21    4.0       59.0        0       0         0          1
# Adarabioyo      Tosin       2020-21    2.0       45.0        0       1         0          0
# Agosto RamÃ­rez Fabricio    2020-21    1.0       40.0        1       0         0          0
#
#                            Current_team  TEAM_TRANSFORM_Arsenal  TEAM_TRANSFORM_Aston Villa  \
# second_name     first_name
# Aarons          Rolando     Newcastle    0                       0
# Abraham         Tammy       Chelsea      0                       0
# Adams           Che         Southampton  0                       0
# Adarabioyo      Tosin       Fulham       0                       0
# Agosto RamÃ­rez Fabricio    Fulham       0                       0
#
#                             TEAM_TRANSFORM_Bournemouth  TEAM_TRANSFORM_Brighton  \
# second_name     first_name
# Aarons          Rolando     0                           0
# Abraham         Tammy       0                           0
# Adams           Che         0                           0
# Adarabioyo      Tosin       0                           0
# Agosto RamÃ­rez Fabricio    0                           0
#
#                             TEAM_TRANSFORM_Burnley  TEAM_TRANSFORM_Chelsea  \
# second_name     first_name
# Aarons          Rolando     0                       0
# Abraham         Tammy       0                       1
# Adams           Che         0                       0
# Adarabioyo      Tosin       0                       0
# Agosto RamÃ­rez Fabricio    0                       0
#
#                             TEAM_TRANSFORM_Crystal Palace  TEAM_TRANSFORM_Everton  \
# second_name     first_name
# Aarons          Rolando     0                              0
# Abraham         Tammy       0                              0
# Adams           Che         0                              0
# Adarabioyo      Tosin       0                              0
# Agosto RamÃ­rez Fabricio    0                              0
#
#                             TEAM_TRANSFORM_Fulham  TEAM_TRANSFORM_Leeds  TEAM_TRANSFORM_Leicester  \
# second_name     first_name
# Aarons          Rolando     0                      0                     0
# Abraham         Tammy       0                      0                     0
# Adams           Che         0                      0                     0
# Adarabioyo      Tosin       1                      0                     0
# Agosto RamÃ­rez Fabricio    1                      0                     0
#
#                             TEAM_TRANSFORM_Liverpool  TEAM_TRANSFORM_Man City  \
# second_name     first_name
# Aarons          Rolando     0                         0
# Abraham         Tammy       0                         0
# Adams           Che         0                         0
# Adarabioyo      Tosin       0                         0
# Agosto RamÃ­rez Fabricio    0                         0
#
#                             TEAM_TRANSFORM_Man Utd  TEAM_TRANSFORM_Newcastle  \
# second_name     first_name
# Aarons          Rolando     0                       1
# Abraham         Tammy       0                       0
# Adams           Che         0                       0
# Adarabioyo      Tosin       0                       0
# Agosto RamÃ­rez Fabricio    0                       0
#
#                             TEAM_TRANSFORM_Norwich  TEAM_TRANSFORM_Sheffield Utd  \
# second_name     first_name
# Aarons          Rolando     0                       0
# Abraham         Tammy       0                       0
# Adams           Che         0                       0
# Adarabioyo      Tosin       0                       0
# Agosto RamÃ­rez Fabricio    0                       0
#
#                             TEAM_TRANSFORM_Southampton  TEAM_TRANSFORM_Spurs  \
# second_name     first_name
# Aarons          Rolando     0                           0
# Abraham         Tammy       0                           0
# Adams           Che         1                           0
# Adarabioyo      Tosin       0                           0
# Agosto RamÃ­rez Fabricio    0                           0
#
#                             TEAM_TRANSFORM_Watford  TEAM_TRANSFORM_West Brom  \
# second_name     first_name
# Aarons          Rolando     0                       0
# Abraham         Tammy       0                       0
# Adams           Che         0                       0
# Adarabioyo      Tosin       0                       0
# Agosto RamÃ­rez Fabricio    0                       0
#
#                             TEAM_TRANSFORM_West Ham  TEAM_TRANSFORM_Wolves  TSS_games_played  \
# second_name     first_name
# Aarons          Rolando     0                        0                      47
# Abraham         Tammy       0                        0                      47
# Adams           Che         0                        0                      47
# Adarabioyo      Tosin       0                        0                      5
# Agosto RamÃ­rez Fabricio    0                        0                      9
#
#                             TSS_average_points_per_game  TSS_total_points_this_season  TSS_rank  \
# second_name     first_name
# Aarons          Rolando     0.000000                     0.0                           1145.0
# Abraham         Tammy       4.042553                     190.0                         44.5
# Adams           Che         2.680851                     126.0                         180.5
# Adarabioyo      Tosin       2.200000                     11.0                          843.5
# Agosto RamÃ­rez Fabricio    0.000000                     0.0                           1145.0
#
#                             L4W_games_played  L4W_average_points_per_game  L4W_total_points  \
# second_name     first_name
# Aarons          Rolando     4                 0.00                         0.0
# Abraham         Tammy       4                 6.00                         24.0
# Adams           Che         4                 5.25                         21.0
# Adarabioyo      Tosin       4                 2.50                         10.0
# Agosto RamÃ­rez Fabricio    4                 0.00                         0.0
#
#                             forecast_points_for_season_sum  forecast_points_for_season_mean  \
# second_name     first_name
# Aarons          Rolando     3.554589                        0.126950
# Abraham         Tammy       117.787417                      4.206693
# Adams           Che         122.318754                      4.368527
# Adarabioyo      Tosin       75.929504                       2.711768
# Agosto RamÃ­rez Fabricio    3.515821                        0.125565
#
#                             forecast_points_N4G_sum  forecast_points_N4G_mean  \
# second_name     first_name
# Aarons          Rolando     0.596454                 0.149113
# Abraham         Tammy       15.648669                3.912167
# Adams           Che         17.329065                4.332266
# Adarabioyo      Tosin       9.795768                 2.448942
# Agosto RamÃ­rez Fabricio    0.439323                 0.109831
#
#                             forecast_points_next_game
# second_name     first_name
# Aarons          Rolando     0.107270
# Abraham         Tammy       4.200414
# Adams           Che         4.604894
# Adarabioyo      Tosin       1.565611
# Agosto RamÃ­rez Fabricio    0.109332

# %% [markdown]
# # Exclusions

# %%
data.index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-edae66003709> in <module>
# ----> 1 data.index['second_name']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in __getitem__(self, key)
#    1931             retval = []
#    1932             for lev, level_codes in zip(self.levels, self.codes):
# -> 1933                 if level_codes[key] == -1:
#    1934                     retval.append(np.nan)
#    1935                 else:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data['Exclude'] = 0


data.loc[data['Current_team'] == 'Aston Villa','Exclude'] = 1
data.loc[data['Current_team'] == 'Newcastle','Exclude'] = 1
data.loc['Kane','Exclude'] = 1

data.loc[data['Exclude'] == 1]
# Out:
#                                       FIX_season  position  cost_today  keeper  defender  \
# second_name         first_name
# Aarons              Rolando            2020-21    3.0       48.0        0       0
# AlmirÃ³n            Miguel             2020-21    3.0       57.0        0       0
# ApolinÃ¡rio de Lira Joelinton CÃ¡ssio  2020-21    4.0       57.0        0       0
# Atsu                Christian          2020-21    3.0       52.0        0       0
# Barkley             Ross               2020-21    3.0       59.0        0       0
# Bree                James              2020-21    2.0       45.0        0       1
# Carroll             Andy               2020-21    4.0       52.0        0       0
# Cash                Matthew            2020-21    2.0       50.0        0       1
# Clark               Ciaran             2020-21    2.0       45.0        0       1
# Darlow              Karl               2020-21    1.0       50.0        1       0
# Davis               Keinan             2020-21    4.0       43.0        0       0
# Dubravka            Martin             2020-21    1.0       49.0        1       0
# Dummett             Paul               2020-21    2.0       44.0        0       1
# El Ghazi            Anwar              2020-21    3.0       57.0        0       0
# El Mohamady         Ahmed              2020-21    2.0       43.0        0       1
# Engels              Bjorn              2020-21    2.0       44.0        0       1
# FernÃ¡ndez          Federico           2020-21    2.0       49.0        0       1
# Fraser              Ryan               2020-21    3.0       56.0        0       0
# Gayle               Dwight             2020-21    4.0       59.0        0       0
# Gillespie           Mark               2020-21    1.0       44.0        1       0
# Grealish            Jack               2020-21    3.0       77.0        0       0
# Guilbert            FrÃ©dÃ©ric         2020-21    2.0       44.0        0       1
# Hause               Kortney            2020-21    2.0       44.0        0       1
# Hayden              Isaac              2020-21    3.0       48.0        0       0
# Heaton              Tom                2020-21    1.0       45.0        1       0
# Hendrick            Jeff               2020-21    3.0       48.0        0       0
# Hourihane           Conor              2020-21    3.0       60.0        0       0
# Ibrahim Hassan      Mahmoud Ahmed      2020-21    3.0       53.0        0       0
# Kane                Harry              2020-21    4.0       109.0       0       0
# Konsa Ngoyo         Ezri               2020-21    2.0       47.0        0       1
# Krafth              Emil               2020-21    2.0       43.0        0       1
# Lansbury            Henri              2020-21    3.0       43.0        0       0
# Lascelles           Jamaal             2020-21    2.0       44.0        0       1
# Lejeune             Florian            2020-21    2.0       43.0        0       1
# Lewis               Jamal              2020-21    2.0       43.0        0       1
# Longstaff           Matthew            2020-21    3.0       49.0        0       0
#                     Sean               2020-21    3.0       48.0        0       0
# Manquillo           Javier             2020-21    2.0       44.0        0       1
# MartÃ­nez           Emiliano           2020-21    1.0       48.0        1       0
# McGinn              John               2020-21    3.0       55.0        0       0
# Mings               Tyrone             2020-21    2.0       53.0        0       1
# Moraes              Wesley             2020-21    4.0       60.0        0       0
# Murphy              Jacob              2020-21    3.0       49.0        0       0
# Muto                Yoshinori          2020-21    4.0       48.0        0       0
# Nakamba             Marvelous          2020-21    3.0       43.0        0       0
# Nyland              Ãrjan             2020-21    1.0       40.0        1       0
# Peleteiro Romallo   JosÃ© Ignacio      2020-21    3.0       59.0        0       0
# Ramsey              Jacob              2020-21    3.0       45.0        0       0
# Ritchie             Matt               2020-21    3.0       49.0        0       0
# Saint-Maximin       Allan              2020-21    3.0       53.0        0       0
# Samatta             Mbwana             2020-21    4.0       59.0        0       0
# SchÃ¤r              Fabian             2020-21    2.0       49.0        0       1
# Shelvey             Jonjo              2020-21    3.0       53.0        0       0
# Soares de Paulo     Douglas Luiz       2020-21    3.0       49.0        0       0
# Steer               Jed                2020-21    1.0       40.0        1       0
# Targett             Matt               2020-21    2.0       45.0        0       1
# Taylor              Neil               2020-21    2.0       43.0        0       1
# TraorÃ©             Bertrand           2020-21    3.0       59.0        0       0
# Vassilev            Indiana            2020-21    4.0       44.0        0       0
# Watkins             Ollie              2020-21    4.0       61.0        0       0
# Watts               Kelland            2020-21    2.0       40.0        0       1
# Wilson              Callum             2020-21    4.0       65.0        0       0
# Yedlin              DeAndre            2020-21    2.0       43.0        0       1
#
#                                        mid-field  striker Current_team  TEAM_TRANSFORM_Arsenal  \
# second_name         first_name
# Aarons              Rolando            1          0        Newcastle    0
# AlmirÃ³n            Miguel             1          0        Newcastle    0
# ApolinÃ¡rio de Lira Joelinton CÃ¡ssio  0          1        Newcastle    0
# Atsu                Christian          1          0        Newcastle    0
# Barkley             Ross               1          0        Aston Villa  0
# Bree                James              0          0        Aston Villa  0
# Carroll             Andy               0          1        Newcastle    0
# Cash                Matthew            0          0        Aston Villa  0
# Clark               Ciaran             0          0        Newcastle    0
# Darlow              Karl               0          0        Newcastle    0
# Davis               Keinan             0          1        Aston Villa  0
# Dubravka            Martin             0          0        Newcastle    0
# Dummett             Paul               0          0        Newcastle    0
# El Ghazi            Anwar              1          0        Aston Villa  0
# El Mohamady         Ahmed              0          0        Aston Villa  0
# Engels              Bjorn              0          0        Aston Villa  0
# FernÃ¡ndez          Federico           0          0        Newcastle    0
# Fraser              Ryan               1          0        Newcastle    0
# Gayle               Dwight             0          1        Newcastle    0
# Gillespie           Mark               0          0        Newcastle    0
# Grealish            Jack               1          0        Aston Villa  0
# Guilbert            FrÃ©dÃ©ric         0          0        Aston Villa  0
# Hause               Kortney            0          0        Aston Villa  0
# Hayden              Isaac              1          0        Newcastle    0
# Heaton              Tom                0          0        Aston Villa  0
# Hendrick            Jeff               1          0        Newcastle    0
# Hourihane           Conor              1          0        Aston Villa  0
# Ibrahim Hassan      Mahmoud Ahmed      1          0        Aston Villa  0
# Kane                Harry              0          1        Spurs        0
# Konsa Ngoyo         Ezri               0          0        Aston Villa  0
# Krafth              Emil               0          0        Newcastle    0
# Lansbury            Henri              1          0        Aston Villa  0
# Lascelles           Jamaal             0          0        Newcastle    0
# Lejeune             Florian            0          0        Newcastle    0
# Lewis               Jamal              0          0        Newcastle    0
# Longstaff           Matthew            1          0        Newcastle    0
#                     Sean               1          0        Newcastle    0
# Manquillo           Javier             0          0        Newcastle    0
# MartÃ­nez           Emiliano           0          0        Aston Villa  0
# McGinn              John               1          0        Aston Villa  0
# Mings               Tyrone             0          0        Aston Villa  0
# Moraes              Wesley             0          1        Aston Villa  0
# Murphy              Jacob              1          0        Newcastle    0
# Muto                Yoshinori          0          1        Newcastle    0
# Nakamba             Marvelous          1          0        Aston Villa  0
# Nyland              Ãrjan             0          0        Aston Villa  0
# Kane                Harry              6.247165                  6.255753
# Konsa Ngoyo         Ezri               4.118150                  4.419802
# Krafth              Emil               0.307870                  0.249278
# Lansbury            Henri              0.239177                  0.238687
# Lascelles           Jamaal             0.838493                  0.589947
# Lejeune             Florian            0.108250                  0.046070
# Lewis               Jamal              3.121652                  2.808233
# Longstaff           Matthew            0.265896                  0.218758
#                     Sean               2.232576                  1.987031
# Manquillo           Javier             2.674317                  2.425777
# MartÃ­nez           Emiliano           3.631165                  3.985748
# McGinn              John               3.055963                  3.245330
# Mings               Tyrone             3.704816                  3.955005
# Moraes              Wesley             0.241338                  0.265818
# Murphy              Jacob              1.380007                  1.088697
# Muto                Yoshinori          0.170170                  0.141188
# Nakamba             Marvelous          0.272368                  0.276750
# Nyland              Ãrjan             0.140251                  0.165427
# Peleteiro Romallo   JosÃ© Ignacio      0.316511                  0.365738
# Ramsey              Jacob              0.235627                  0.240488
# Ritchie             Matt               1.172919                  1.139312
# Saint-Maximin       Allan              1.732507                  1.639796
# Samatta             Mbwana             0.433615                  0.469762
# SchÃ¤r              Fabian             1.234651                  0.981173
# Shelvey             Jonjo              2.119098                  2.018596
# Soares de Paulo     Douglas Luiz       3.407802                  3.708425
# Steer               Jed                0.146982                  0.186673
# Targett             Matt               4.399850                  4.650828
# Taylor              Neil               0.196175                  0.211272
# TraorÃ©             Bertrand           2.535336                  2.850820
# Vassilev            Indiana            0.315423                  0.311003
# Watkins             Ollie              4.578646                  4.768209
# Watts               Kelland            0.094339                  0.041590
# Wilson              Callum             6.257462                  6.165144
# Yedlin              DeAndre            0.131440                  0.075911
#
#                                        Exclude  Player_selected
# second_name         first_name
# Aarons              Rolando            1        0.0
# AlmirÃ³n            Miguel             1        0.0
# ApolinÃ¡rio de Lira Joelinton CÃ¡ssio  1        0.0
# Atsu                Christian          1        0.0
# Barkley             Ross               1        0.0
# Bree                James              1        0.0
# Carroll             Andy               1        0.0
# Cash                Matthew            1        0.0
# Clark               Ciaran             1        0.0
# Darlow              Karl               1        0.0
# Davis               Keinan             1        0.0
# Dubravka            Martin             1        0.0
# Dummett             Paul               1        0.0
# El Ghazi            Anwar              1        0.0
# El Mohamady         Ahmed              1        0.0
# Engels              Bjorn              1        0.0
# FernÃ¡ndez          Federico           1        0.0
# Fraser              Ryan               1        0.0
# Gayle               Dwight             1        0.0
# Gillespie           Mark               1        0.0
# Grealish            Jack               1        0.0
# Guilbert            FrÃ©dÃ©ric         1        0.0
# Hause               Kortney            1        0.0
# Hayden              Isaac              1        0.0
# Heaton              Tom                1        0.0
# Hendrick            Jeff               1        0.0
# Hourihane           Conor              1        0.0
# Ibrahim Hassan      Mahmoud Ahmed      1        0.0
# Kane                Harry              1        1.0
# Konsa Ngoyo         Ezri               1        0.0
# Krafth              Emil               1        0.0
# Lansbury            Henri              1        0.0
# Lascelles           Jamaal             1        0.0
# Lejeune             Florian            1        0.0
# Lewis               Jamal              1        0.0
# Longstaff           Matthew            1        0.0
#                     Sean               1        0.0
# Manquillo           Javier             1        0.0
# MartÃ­nez           Emiliano           1        0.0
# McGinn              John               1        0.0
# Mings               Tyrone             1        0.0
# Moraes              Wesley             1        0.0
# Murphy              Jacob              1        0.0
# Muto                Yoshinori          1        0.0
# Nakamba             Marvelous          1        0.0
# Nyland              Ãrjan             1        0.0
# Peleteiro Romallo   JosÃ© Ignacio      1        0.0
# Ramsey              Jacob              1        0.0
# Ritchie             Matt               1        0.0
# Saint-Maximin       Allan              1        0.0
# Samatta             Mbwana             1        0.0
# SchÃ¤r              Fabian             1        0.0
# Shelvey             Jonjo              1        0.0
# Soares de Paulo     Douglas Luiz       1        0.0
# Steer               Jed                1        0.0
# Targett             Matt               1        0.0
# Taylor              Neil               1        0.0
# TraorÃ©             Bertrand           1        0.0
# Vassilev            Indiana            1        0.0
# Watkins             Ollie              1        0.0
# Watts               Kelland            1        0.0
# Wilson              Callum             1        0.0
# Yedlin              DeAndre            1        0.0

# %% [markdown]
# ## Choose team from scratch

# %%
def the_draft(data, objective_func):
    
    the_draft = pulp.LpProblem("the_draft", pulp.LpMaximize)
    
    # Decision variable
    player_selected = pulp.LpVariable.dicts("selected",
                                     (name for name in data.index),
                                     cat='Binary')
    
    # Objective function 
    the_draft += pulp.lpSum([data.loc[name, objective_func] * player_selected[name]  for name in data.index])
    
    # Constraints
    # 2 GK
    the_draft += pulp.lpSum([data.loc[name, 'keeper'] * player_selected[name]  for name in data.index]) == 2

    # 5 DEF
    the_draft += pulp.lpSum([data.loc[name, 'defender'] * player_selected[name]  for name in data.index]) == 5

    # 5 MID
    the_draft += pulp.lpSum([data.loc[name, 'mid-field'] * player_selected[name]  for name in data.index]) == 5

    # 3 FOR
    the_draft += pulp.lpSum([data.loc[name, 'striker'] * player_selected[name]  for name in data.index]) == 3

    # Total cost < £100M
    the_draft += pulp.lpSum([data.loc[name, 'cost_today'] * player_selected[name]  for name in data.index]) <= 1000

    # No more than 3 from each team
    for col in [c for c in data.columns if str.startswith(c, 'TEAM_TRANSFORM')]:
        the_draft += pulp.lpSum([data.loc[name, col] * player_selected[name]  for name in data.index]) <=3
        

    # No one who's been excluded (above)
    the_draft += pulp.lpSum([data.loc[name, 'Exclude'] * player_selected[name]  for name in data.index]) == 0 
    
    the_draft.solve()
    print("Optimiser status: ", pulp.LpStatus[the_draft.status])
    
    output = []
    
    for name in data.index:
        var_output ={'Name': name,
                    'Player_selected': player_selected[name].varValue}
        output.append(var_output)
        
    output_df = pd.DataFrame.from_records(output).set_index(['Name'])

    return output_df

# %%
optimiser_selection = the_draft(data, 'forecast_points_N4G_sum')
# Out:
# Optimiser status:  Optimal

# %%
data['Player_selected'] = optimiser_selection['Player_selected']

# %% [markdown]
# # The team

# %%
team = data.loc[data['Player_selected'] == True]
team = team.sort_values('forecast_points_next_game', ascending = False)
team['Forecast_file'] = latest_file_address
team[['position','L4W_average_points_per_game','forecast_points_N4G_mean']]
# Out:
#                                position  L4W_average_points_per_game  forecast_points_N4G_mean
# second_name      first_name
# Calvert-Lewin    Dominic       4.0       7.00                         6.528023
# Son              Heung-Min     3.0       4.50                         6.317149
# Mahrez           Riyad         3.0       6.50                         5.813713
# Chilwell         Benjamin      2.0       7.25                         5.834718
# James            Reece         2.0       5.50                         5.765249
# Borges Fernandes Bruno Miguel  3.0       10.00                        5.996441
# Zouma            Kurt          2.0       6.75                         5.291801
# Vardy            Jamie         4.0       6.25                         5.233678
# Fabianski        Lukasz        1.0       7.25                         5.250856
# Adams            Che           4.0       5.25                         4.332266
# GroÃ            Pascal        3.0       6.00                         3.831349
# Dallas           Stuart        2.0       4.75                         4.153138
# Ogbonna          Angelo        2.0       5.25                         3.854798
# Meslier          Illan         1.0       4.75                         3.716965
# Lomba Neto       Pedro         3.0       7.00                         3.865303

# %%
GW = next_game['FIX_GW'].unique()[0]

team.to_csv('Teams/GW_' + str(GW) + '.csv')

# %%
team.agg({'cost_today':'sum',
          'keeper': 'sum',
          'defender': 'sum',
          'mid-field': 'sum',
          'striker': 'sum',
          'TSS_average_points_per_game' : 'sum',
          'TSS_average_minutes_per_game' : 'mean',
          'L4W_average_points_per_game' : 'sum',
          'L4W_average_minutes_per_game' : 'mean',
          'forecast_points_for_season_sum' : 'sum',
          'forecast_points_for_season_mean': 'sum',
          'forecast_points_N4G_sum' : 'sum',
          'forecast_points_N4G_mean' : 'sum',
          'forecast_points_next_game': 'sum'})

# %%
team['Current_team'].value_counts()

# %% [markdown]
# # Look at recent performance of team

# %%
list_of_files = glob.glob('Data/Input_data/*')
latest_file = max(list_of_files, key=os.path.getctime)
print('Opening ', latest_file)

games_to_date = pd.read_csv(latest_file)
games_to_date = games_to_date.loc[games_to_date['forecast'] == 0]

# %%
def plot_player_performance(df, player_list,season = '2019-20', smooth = False):
    df = df.loc[(df['name'].isin(player_list)) & (df['FIX_season'] == season)]
    
    for player in df['name'].unique():
        
        player_df = df.loc[df['name'] == player]
        
        player_df['points_smoothed'] = player_df['total_points'].transform(lambda x: x.ewm(halflife=10).mean())
        
        season_av = player_df['total_points'].mean()
        
        plt.title(str(player) + ' - season av. =' + str(season_av))
        plt.scatter(player_df['FIX_GW'],player_df['total_points'], marker = 'x')
        plt.plot(player_df['FIX_GW'],player_df['points_smoothed'])
        plt.axhline(season_av, c = 'k', linestyle = ":")

        plt.grid()
        plt.show()

# %%
plot_player_performance(games_to_date, team.index.to_list())

# %%
ranks_2019 = pd.DataFrame(input_df.loc[input_df['FIX_season'] == '2019-20'].groupby('name').total_points.mean().sort_values(ascending = False))
ranks_2019['2019_rank'] = input_df.loc[input_df['FIX_season'] == '2019-20'].groupby('name').total_points.mean().sort_values(ascending = False).rank(ascending = False,method = 'dense')
ranks_2019['selected'] = np.where(ranks_2019.index.isin(team.index.to_list()), 1 ,0)
ranks_2019['position'] = input_df.sort_values(by = 'FIX_season').groupby('name')['position'].last()
ranks_2019['cost'] = input_df.sort_values(by = 'FIX_season').groupby('name')['cost_today'].last()/10

# %%
# ranks_2019.head(20)

# %%
print("Average per game with this team",ranks_2019.loc[ranks_2019['selected'] == 1]['total_points'].sum())
ranks_2019.loc[ranks_2019['selected'] == 1].head(50).sort_values('position')

# %%
team_file = 'Teams/Current_team.csv'
