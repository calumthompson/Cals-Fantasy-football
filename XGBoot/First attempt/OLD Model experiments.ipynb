# %%
import datetime as dt
from time import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from numpy.random import randint
from scipy.stats import uniform
from sklearn import metrics
from sklearn.ensemble import ExtraTreesRegressor, RandomForestClassifier
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import plot_confusion_matrix, r2_score
from sklearn.model_selection import (GridSearchCV, RandomizedSearchCV,
                                     cross_val_predict, cross_val_score,
                                     train_test_split)
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Import training datasets

# %%
historic_df = pd.read_csv('datasets/historic_data.csv')
historic_df = historic_df.dropna()
historic_df.head()
# Out:
#    PLAYER_id         PLAYER_name PLAYER_Team  PLAYER_position  PLAYER_GW  \
# 4        534  Aaron_Connolly_534    Brighton                4          8
# 5        534  Aaron_Connolly_534    Brighton                4          9
# 6        534  Aaron_Connolly_534    Brighton                4         10
# 7        534  Aaron_Connolly_534    Brighton                4         11
# 8        534  Aaron_Connolly_534    Brighton                4         12
#
#   PLAYER_Fixture_date  PLAYER_Opponent_id PLAYER_Opponent  FORECAST  \
# 4          2019-10-05                  17           Spurs         0
# 5          2019-10-19                   2     Aston Villa         0
# 6          2019-10-26                   8         Everton         0
# 7          2019-11-02                  14         Norwich         0
# 8          2019-11-10                  12         Man Utd         0
#
#    FIX_Home?  ...  LSS_df_avg_GK_saves  LSS_df_avg_GK_DEF_goals_conceded  \
# 4          1  ...                  0.0                          0.527473
# 5          0  ...                  0.0                          0.527473
# 6          1  ...                  0.0                          0.527473
# 7          1  ...                  0.0                          0.527473
# 8          0  ...                  0.0                          0.527473
#
#    LSS_df_avg_GK_DEF_MID_clean_sheets  LSS_df_avg_selected_by  \
# 4                            0.131868           167753.065934
# 5                            0.131868           167753.065934
# 6                            0.131868           167753.065934
# 7                            0.131868           167753.065934
# 8                            0.131868           167753.065934
#
#    LSS_df_avg_cost  LSS_df_no_player_history  TARGET_minutes  \
# 4        59.615385                       1.0            79.0
# 5        59.615385                       1.0            45.0
# 6        59.615385                       1.0            79.0
# 7        59.615385                       1.0            85.0
# 8        59.615385                       1.0            45.0
#
#    TARGET_total_points  TARGET_total_points_BIN_EVEN  \
# 4                 13.0                           6.0
# 5                  1.0                           2.0
# 6                  8.0                           4.0
# 7                  2.0                           2.0
# 8                  1.0                           2.0
#
#    TARGET_total_points_BIN_QUAR
# 4                           4.0
# 5                           1.0
# 6                           4.0
# 7                           2.0
# 8                           1.0
#
# [5 rows x 107 columns]

# %%
historic_df.groupby('PLAYER_position')['PLAYER_name'].count()
# Out:
# PLAYER_position
# 1    1623
# 2    4767
# 3    5737
# 4    1896
# Name: PLAYER_name, dtype: int64

# %%
historic_df_KEEPER = historic_df.loc[historic_df['PLAYER_position'] == 1]
historic_df_DEF = historic_df.loc[historic_df['PLAYER_position'] == 2]
historic_df_MID = historic_df.loc[historic_df['PLAYER_position'] == 3]
historic_df_FOR = historic_df.loc[historic_df['PLAYER_position'] == 4]

# %%
historic_df_FOR = historic_df_FOR.drop(columns = [c for c in historic_df_FOR.columns if "clean" in c])
historic_df_FOR = historic_df_FOR.drop(columns = [c for c in historic_df_FOR.columns if "conceded" in c])
historic_df_FOR = historic_df_FOR.drop(columns = [c for c in historic_df_FOR.columns if "save" in c])

historic_df_MID = historic_df_MID.drop(columns = [c for c in historic_df_MID.columns if "conceded" in c])
historic_df_MID = historic_df_MID.drop(columns = [c for c in historic_df_MID.columns if "save" in c])

historic_df_DEF = historic_df_DEF.drop(columns = [c for c in historic_df_DEF.columns if "save" in c])

# %% [markdown]
# # Model attempts
# - Using historic_df_MID as test data

# %%
def plot_results(y_actual,y_predicted):
    plt.scatter(y_predicted,y_actual, marker = 'x')
    
    plt.grid()
    plt.xlim(left = 0)
    plt.ylim(bottom = 0)
    
    plt.xlabel('y_predicted')
    plt.xlabel('y_actual')
    
    print("R2: ", r2_score(y_test, fit))

# %% [markdown]
# ## Random forest Regression

# %%
def get_columns_to_use(feature_ranking,rank_cutoff,required_prefix = None):
    
    if required_prefix != None:
        prefix_columns = [c for c in feature_ranking.index if str.startswith(c, required_prefix)]
    else:
        prefix_columns = []
    
    model_columns = prefix_columns 
    feature_ranking = feature_ranking.drop(index = model_columns)
    
    return np.concatenate((model_columns,feature_ranking.iloc[:rank_cutoff].index.values.tolist()))

# %%
def assess_feat_importance_REG(df, X_cols=('FIX', 'LW', 'L4W', 'TSS', 'LSS'), y_cols='TARGET_total_points', plot = True, suppress_return = False):

    X = df[[c for c in df.columns if str.startswith(c, X_cols)]]
    y = df[y_cols]

    model = RandomForestRegressor()#ExtraTreesRegressor()
    model.fit(X, y)

    feat_importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)

    if plot:
    # plot graph of feature importances for better visualization
        fig = plt.figure(figsize=[25, 6])
        ax = fig.add_subplot(111)
        ax.plot(feat_importances)
        ax.tick_params(axis='x', rotation=90)
        ax.set_xlim(-1, X.shape[1])
        ax.set_ylim(bottom = 0)
        ax.grid()

        plt.show()

    if suppress_return == False:
        return feat_importances

# %%
feature_ranking_MID_REG = assess_feat_importance_REG(historic_df_MID)
columns_MID_REG = get_columns_to_use(feature_ranking_MID_REG, rank_cutoff = 50, required_prefix=('FIX'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-59f4ec8c8d07> in <module>
# ----> 1 feature_ranking_MID_REG = assess_feat_importance_REG(historic_df_MID)
#       2 columns_MID_REG = get_columns_to_use(feature_ranking_MID_REG, rank_cutoff = 50, required_prefix=('FIX'))
#
# <ipython-input-8-c20fc893b9bd> in assess_feat_importance_REG(df, X_cols, y_cols, plot, suppress_return)
#       4     y = df[y_cols]
#       5
# ----> 6     model = RandomForestRegressor()#ExtraTreesRegressor()
#       7     model.fit(X, y)
#       8
#
# NameError: name 'RandomForestRegressor' is not defined

# %%
start = dt.datetime.now()

X = historic_df_MID[columns_MID_REG]
y = historic_df_MID['TARGET_total_points']

# Create test and training dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Perform grid search to tune hyperparametres
gsc = GridSearchCV(estimator=RandomForestRegressor()
                  ,param_grid={'max_depth': range(3, 7),'n_estimators': (10, 50, 100, 1000)}
                  ,cv=5, scoring='neg_mean_squared_error', verbose=0, n_jobs=-1)

grid_result = gsc.fit(X_train, y_train)
best_params = grid_result.best_params_

print(best_params)

# Initialise regressor
RFRegressor = RandomForestRegressor(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"]
                                   ,random_state=False, verbose=False)

# # Perform K-Fold cross-validation
# scores = cross_val_score(RFRegressor, X_train, y_train, cv=10, scoring='neg_mean_absolute_error')

# # Fit data
# predictions = cross_val_predict(RFRegressor, X_train, y_train, cv=10)


# Fit
RFRegressor.fit(X_train,y_train)

prediction = RFRegressor.predict(X_test)

print("Time taken: ", dt.datetime.now() - start )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6fac0cf633c8> in <module>
#       1 start = dt.datetime.now()
#       2
# ----> 3 X = historic_df_MID[columns_MID_REG]
#       4 y = historic_df_MID['TARGET_total_points']
#       5
#
# NameError: name 'columns_MID_REG' is not defined

# %%
plt.scatter(y_test, prediction, marker = 'x')
plt.grid()
plt.xlim(left = 0)
plt.ylim(bottom = 0)
r2_score(y_test, prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b1b9917402cd> in <module>
# ----> 1 plt.scatter(y_test, prediction, marker = 'x')
#       2 plt.grid()
#       3 plt.xlim(left = 0)
#       4 plt.ylim(bottom = 0)
#       5 r2_score(y_test, prediction)
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ## Random forest classifier

# %%
historic_df.groupby('TARGET_total_points_BIN_QUAR')['TARGET_total_points'].agg([np.min,np.max])
# Out:
#                               amin  amax
# TARGET_total_points_BIN_QUAR
# 0.0                           -6.0   0.0
# 1.0                            1.0   1.0
# 2.0                            2.0   2.0
# 3.0                            3.0   5.0
# 4.0                            6.0  24.0

# %%
def assess_feat_importance_CAT(df, X_cols=('FIX', 'LW', 'L4W', 'TSS', 'LSS'), y_cols='TARGET_total_points_BIN_QUAR', plot = True, suppress_return = False):

    X = df[[c for c in df.columns if str.startswith(c, X_cols)]]
    y = df[y_cols]

    model = RandomForestClassifier()
    model.fit(X, y)

    feat_importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)

    if plot:
    # plot graph of feature importances for better visualization
        fig = plt.figure(figsize=[25, 6])
        ax = fig.add_subplot(111)
        ax.plot(feat_importances)
        ax.tick_params(axis='x', rotation=90)
        ax.set_xlim(-1, X.shape[1])
        ax.set_ylim(bottom = 0)
        ax.grid()

        plt.show()

    if suppress_return == False:
        return feat_importances

# %%
feature_ranking_MID_CAT = assess_feat_importance_CAT(historic_df_MID)
columns_MID_CAT = get_columns_to_use(feature_ranking_MID_CAT, rank_cutoff = 90, required_prefix=('FIX'))

# %%
start = dt.datetime.now()

X = historic_df_MID[columns_MID_CAT]
y = historic_df_MID['TARGET_total_points_BIN_QUAR']

# Create test and training dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Perform grid search to tune hyperparametres
gsc = GridSearchCV(estimator=RandomForestClassifier()
                  ,param_grid={'max_depth': range(3, 7),'n_estimators': (10, 50, 100, 1000)}
                  ,cv=5, scoring='neg_mean_squared_error', verbose=0, n_jobs=-1)

grid_result = gsc.fit(X_train, y_train)
best_params = grid_result.best_params_

print(best_params)

# Initialise regressor
RFClassifier = RandomForestClassifier(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"]
                                   ,random_state=False, verbose=False)

# RFClassifier = RandomForestClassifier(max_depth=4, n_estimators=100
#                                    ,random_state=False, verbose=False)

# # Perform K-Fold cross-validation
# scores = cross_val_score(RFRegressor, X_train, y_train, cv=10, scoring='neg_mean_absolute_error')

# # Fit data
# predictions = cross_val_predict(RFRegressor, X_train, y_train, cv=10)


# Fit
RFClassifier.fit(X_train,y_train)

prediction = RFClassifier.predict(X_test)

print("Time taken: ", dt.datetime.now() - start )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-7a9b6ac575db> in <module>
#      12                   ,cv=5, scoring='neg_mean_squared_error', verbose=0, n_jobs=-1)
#      13
# ---> 14 grid_result = gsc.fit(X_train, y_train)
#      15 best_params = grid_result.best_params_
#      16
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
print(metrics.accuracy_score(y_test, prediction))

plot_confusion_matrix(RFClassifier, X_test, y_test)

# %% [markdown]
# ## Linear regression

# %%
# Compute correlations
cor = historic_df_MID.corr()

#Correlation with output variable
cor_target = abs(cor["TARGET_total_points"])
cor_target.drop(index = [c for c in cor_target.index if str.startswith(c, ('TARGET'))], inplace = True)

cor_target.sort_values(ascending = False)

relevant_features = cor_target[cor_target>0.4]
relevant_features
# Out:
# LW_minutes_played         0.445187
# L4W_avg_total_points      0.440366
# L4W_avg_minutes_played    0.450197
# L4W_avg_creativity        0.408141
# L4W_avg_influence         0.427217
# L4W_avg_threat            0.410819
# TSS_avg_total_points      0.468907
# TSS_stdev_total_points    0.418618
# TSS_avg_minutes_played    0.431957
# TSS_avg_creativity        0.407434
# TSS_avg_influence         0.449678
# TSS_stdev_influence       0.426931
# TSS_avg_threat            0.414008
# TSS_stdev_threat          0.400120
# Name: TARGET_total_points, dtype: float64

# %%
X = historic_df_MID[relevant_features.index.values].drop(columns = 'TSS_avg_total_points')
y = historic_df_MID['TARGET_total_points']

# Create test and training dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

regressor = LinearRegression() 
regressor.fit(X_train,y_train)
fit = regressor.predict(X_test) 

print('R^2: ',metrics.r2_score(y_test,fit))

plt.plot(y_test,y_test, linestyle = '--', c= 'k')
plt.scatter(fit,y_test , marker = 'x')
plt.grid()
plt.xlim(left = 0)
plt.ylim(bottom = 0)
plt.ylabel('y_test')
plt.xlabel('prediction')

plt.show()
# Out:
# R^2:  0.2378070898018183

# %%
print("Underestimating ",np.mean(np.where(fit < y_test,1,0)), '%')
# Out:
# Underestimating  0.2529039070749736 %

# %% [markdown]
# ## Artificial neural network

# %% [markdown]
# ### Create training set and scale

# %%
X = historic_df_MID[[c for c in historic_df_MID.columns if str.startswith(c, ('FIX', 'LW', 'L4W', 'TSS', 'LSS'))]]
y = historic_df_MID['TARGET_total_points']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

a, evaluate_set, c, d = train_test_split(historic_df_MID, y, test_size=0.33, random_state=42)

scaler = StandardScaler()

# Fit only to the training data
scaler.fit(X_train)
StandardScaler(copy=True, with_mean=True, with_std=True)

# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Tune hyperparameters

# %%
mlp = MLPRegressor()
param_list = {"hidden_layer_sizes": [np.repeat(100,1),np.repeat(100,2),np.repeat(100,3),np.repeat(100,4),np.repeat(100,5)]
             ,"max_iter":[500,1000,3000,5000] 
             ,"activation": ["identity", "logistic", "tanh", "relu"]}

gsc = RandomizedSearchCV(estimator=mlp, param_distributions=param_list, verbose = 100, n_iter = 50, n_jobs = -1  )

grid_result = gsc.fit(X_train, y_train)
best_params = grid_result.best_params_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Memmapping (shape=(3843, 82), dtype=float64) to new file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   22.4s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   24.4s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   25.8s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   25.8s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   30.2s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   32.9s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   32.9s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   33.8s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   34.4s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   35.2s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   36.1s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   36.2s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   36.7s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   36.9s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   37.5s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   38.1s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   38.5s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   38.7s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   39.7s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   39.9s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   46.0s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   46.3s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   47.6s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   48.2s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   48.4s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   49.2s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   49.8s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   50.0s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   51.3s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   54.2s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   57.7s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   58.7s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   59.9s
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  1.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.4min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  1.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  1.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  1.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  1.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  1.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  1.9min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  2.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  2.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  2.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  2.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  2.3min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  2.3min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  2.3min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  2.4min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  2.4min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  2.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  2.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  2.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  2.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  2.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  2.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  2.6min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  2.6min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  2.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  2.9min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  2.9min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  2.9min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  3.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  3.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  3.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  3.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  3.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  3.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  3.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  3.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  3.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  3.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  3.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  3.3min
# ...
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:  9.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:  9.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:  9.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:  9.0min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:  9.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:  9.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:  9.1min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:  9.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:  9.2min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(3,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  9.5min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:  9.7min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(2,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:  9.7min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:  9.7min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:  9.7min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:  9.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:  9.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(1,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:  9.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:  9.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:  9.8min
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3074,), dtype=int64).
# Pickling array (shape=(769,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# Memmapping (shape=(3843, 82), dtype=float64) to old file /var/folders/x0/h9zbtpk5131g7yx68t8c3j9w0000gn/T/joblib_memmapping_folder_58105_9995083310/58105-112400308432-e619b04dadce4f028b2c1ab58938fc33.pkl
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3843,), dtype=float64).
# Pickling array (shape=(3843,), dtype=int64).
# Pickling array (shape=(3075,), dtype=int64).
# Pickling array (shape=(768,), dtype=int64).
# Pickling array (shape=(4,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 246 out of 250 | elapsed:  9.9min remaining:    9.6s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed: 10.0min finished

# %%
best_params
# Out:
# {'max_iter': 1000,
#  'hidden_layer_sizes': array([100, 100, 100, 100]),
#  'activation': 'identity'}

# %% [markdown]
# ### Execute

# %%
mlp = MLPRegressor(max_iter = 1000
                  ,hidden_layer_sizes = (100, 100, 100, 100)
                  ,activation = 'identity')


mlp.fit(X_train,y_train)
fit = mlp.predict(X_test)

plot_results(y_test,fit)
# Out:
# R2:  0.21877107666719497

# %%
evaluate_set.insert(1,'prediction',fit)

# %%
evaluate_set
# Out:
#        PLAYER_id  prediction                            PLAYER_name  \
# 1647         101    1.498035                    Ashley_Westwood_101
# 16064        176    2.084840                      Wilfred_Ndidi_176
# 13282        173    0.110256                     Rachid_Ghezzal_173
# 13382        456    0.215796                     Ravel_Morrison_456
# 7340         138    2.726887                     James_McArthur_138
# 13328        214    4.550879                    Raheem_Sterling_214
# 4921         576    0.588326                   Emile_Smith Rowe_576
# 2194         152    1.561978     Bernard_Anício Caldeira Duarte_152
# 681          193    3.080596            Alex_Oxlade-Chamberlain_193
# 5106         346    1.249301                        Erik_Lamela_346
# 5063         350    0.375261                          Eric_Dier_350
# 15465        371    0.444899                      Tom_Cleverley_371
# 13776        393    2.003971                   Robert_Snodgrass_393
# 6161         180    0.532784                    Hamza_Choudhury_180
# 3614          81    0.131659                         Dan_Gosling_81
# 5803         565    0.066652                     Gavin_Kilkenny_565
# 13483        489    2.539015                       Reiss_Nelson_489
# 12193        374    0.092112                 Nathaniel_Chalobah_374
# 354          417    1.537543                       Adama_Traoré_417
# 3127         343    1.346672                  Christian_Eriksen_343
# 9820         216    0.702723                         Leroy_Sané_216
# 11835        158    0.123004                Morgan_Schneiderlin_158
# 10655        300    0.029936                         Mark_Duffy_300
# 10685        396    2.084313                         Mark_Noble_396
# 412          155   -0.152123                    Ademola_Lookman_155
# 12991        114    1.604223            Pedro_Rodríguez Ledesma_114
# 6276         505    1.734206                       Harry_Wilson_505
# 6729         525    2.685455                       Ismaïla_Sarr_525
# 13225        325    2.670577              Pierre-Emile_Højbjerg_325
# 2591         453    0.655853                    Callum_Robinson_453
# ...          ...         ...                                    ...
# 1216         480    0.285440                          Andy_King_480
# 14236        414    3.030739         Rúben Diogo_da Silva Neves_414
# 14136         75    3.523137                         Ryan_Fraser_75
# 1469          30    3.601010                      Anwar_El Ghazi_30
# 8635         490    0.609021                     Joseph_Willock_490
# 13488        489    0.483109                       Reiss_Nelson_489
# 13270        173    0.387615                     Rachid_Ghezzal_173
# 680          193    2.130632            Alex_Oxlade-Chamberlain_193
# 10206        441    0.556326                       Luke_Freeman_441
# 7386         200    1.021553                       James_Milner_200
# 1120         135    1.903620                    Andros_Townsend_135
# 11877        288    0.230885                     Moritz_Leitner_288
# 12866        238    3.698346                         Paul_Pogba_238
# 15548        290    2.215319                        Tom_Trybull_290
# 7813          82    2.838815                     Jefferson_Lerma_82
# 7065         483    0.051853                       Jacob_Murphy_483
# 14558        270    0.026145                     Sean_Longstaff_270
# 1809         265    2.973561                        Ayoze_Pérez_265
# 13146        476    2.227303                     Philip_Billing_476
# 2078         472    0.335295                         Ben_Osborn_472
# 10481        285    1.458689                  Marco_Stiepermann_285
# 15263        560    0.209475                       Taylor_Perry_560
# 6601         156    0.147247                      Idrissa_Gueye_156
# 14284        192    3.787449                         Sadio_Mané_192
# 13735        462    0.259259  Robert Kenedy_Nunes do Nascimento_462
# 16452         53    0.255294                       Yves_Bissouma_53
# 4435         517    1.237388                       Dennis_Praet_517
# 3679         469    0.739078          Daniel_Ceballos Fernández_469
# 7355         157    0.295145                     James_McCarthy_157
# 9333         215    5.010391                    Kevin_De Bruyne_215
#
#           PLAYER_Team  PLAYER_position  PLAYER_GW PLAYER_Fixture_date  \
# 1647          Burnley                3         18          2019-12-21
# 16064       Leicester                3         12          2019-11-09
# 13282       Leicester                3         21          2020-01-01
# 13382   Sheffield Utd                3          6          2019-09-21
# 7340   Crystal Palace                3         24          2020-01-21
# 13328        Man City                3          9          2019-10-19
# 4921          Arsenal                3         21          2020-01-01
# 2194          Everton                3          8          2019-10-05
# 681         Liverpool                3         29          2020-03-07
# 5106            Spurs                3         12          2019-11-09
# 5063            Spurs                3         21          2020-01-01
# 15465         Watford                3         18          2019-12-22
# 13776        West Ham                3         27          2020-02-24
# 6161        Leicester                3         17          2019-12-14
# 3614      Bournemouth                3         14          2019-11-30
# 5803      Bournemouth                3         28          2020-02-29
# 13483         Arsenal                3         21          2020-01-01
# 12193         Watford                3         28          2020-02-29
# 354            Wolves                3          6          2019-09-22
# 3127            Spurs                3         18          2019-12-22
# 9820         Man City                3         28          2020-03-08
# 11835         Everton                3          7          2019-09-28
# 10655   Sheffield Utd                3         14          2019-12-01
# 10685        West Ham                3         16          2019-12-09
# 412           Everton                3         12          2019-11-09
# 12991         Chelsea                3         17          2019-12-14
# 6276      Bournemouth                3         22          2020-01-12
# 6729          Watford                3          8          2019-10-05
# 13225     Southampton                3         22          2020-01-11
# 2591    Sheffield Utd                3         28          2020-03-07
# ...               ...              ...        ...                 ...
# 1216        Leicester                3         17          2019-12-14
# 14236          Wolves                3         17          2019-12-15
# 14136     Bournemouth                3         11          2019-11-02
# 1469      Aston Villa                3          7          2019-09-28
# 8635          Arsenal                3         14          2019-12-01
# 13488         Arsenal                3         26          2020-02-16
# 13270       Leicester                3          9          2019-10-19
# 680         Liverpool                3         28          2020-02-29
# 10206   Sheffield Utd                3         11          2019-11-02
# 7386        Liverpool                3         12          2019-11-10
# 1120   Crystal Palace                3          8          2019-10-05
# 11877         Norwich                3         20          2019-12-28
# 12866         Man Utd                3          8          2019-10-06
# 15548         Norwich                3         15          2019-12-04
# 7813      Bournemouth                3         19          2019-12-26
# 7065        Newcastle                3         16          2019-12-08
# 14558       Newcastle                3         16          2019-12-08
# 1809        Leicester                3         19          2019-12-26
# 13146     Bournemouth                3         29          2020-03-07
# 2078    Sheffield Utd                3         27          2020-02-22
# 10481         Norwich                3         14          2019-12-01
# 15263          Wolves                3         27          2020-02-23
# 6601          Everton                3          9          2019-10-19
# 14284       Liverpool                3          7          2019-09-28
# 13735         Chelsea                3         28          2020-02-29
# 16452        Brighton                3         13          2019-11-23
# 4435        Leicester                3         27          2020-02-22
# 3679          Arsenal                3         16          2019-12-09
# 7355   Crystal Palace                3         10          2019-10-27
# 9333         Man City                3         22          2020-01-12
#
#        PLAYER_Opponent_id PLAYER_Opponent  FORECAST  ...  \
# 1647                    3     Bournemouth         0  ...
# 16064                   1         Arsenal         0  ...
# 13282                  13       Newcastle         0  ...
# 13382                   8         Everton         0  ...
# 7340                   16     Southampton         0  ...
# 13328                   7  Crystal Palace         0  ...
# 4921                   12         Man Utd         0  ...
# 2194                    5         Burnley         0  ...
# 681                     3     Bournemouth         0  ...
# 5106                   15   Sheffield Utd         0  ...
# 5063                   16     Southampton         0  ...
# 15465                  12         Man Utd         0  ...
# 13776                  10       Liverpool         0  ...
# 6161                   14         Norwich         0  ...
# 3614                   17           Spurs         0  ...
# 5803                    6         Chelsea         0  ...
# 13483                  12         Man Utd         0  ...
# 12193                  10       Liverpool         0  ...
# 354                     7  Crystal Palace         0  ...
# 3127                    6         Chelsea         0  ...
# 9820                   12         Man Utd         0  ...
# 11835                  11        Man City         0  ...
# 10655                  20          Wolves         0  ...
# 10685                   1         Arsenal         0  ...
# 412                    16     Southampton         0  ...
# 12991                   3     Bournemouth         0  ...
# 6276                   18         Watford         0  ...
# 6729                   15   Sheffield Utd         0  ...
# 13225                   9       Leicester         0  ...
# 2591                   14         Norwich         0  ...
# ...                   ...             ...       ...  ...
# 1216                   14         Norwich         0  ...
# 14236                  17           Spurs         0  ...
# 14136                  12         Man Utd         0  ...
# 1469                    5         Burnley         0  ...
# 8635                   14         Norwich         0  ...
# 13488                  13       Newcastle         0  ...
# 13270                   5         Burnley         0  ...
# 680                    18         Watford         0  ...
# 10206                   5         Burnley         0  ...
# 7386                   11        Man City         0  ...
# 1120                   19        West Ham         0  ...
# 11877                  17           Spurs         0  ...
# 12866                  13       Newcastle         0  ...
# 15548                  16     Southampton         0  ...
# 7813                    1         Arsenal         0  ...
# 7065                   16     Southampton         0  ...
# 14558                  16     Southampton         0  ...
# 1809                   10       Liverpool         0  ...
# 13146                  10       Liverpool         0  ...
# 2078                    4        Brighton         0  ...
# 10481                   1         Arsenal         0  ...
# 15263                  14         Norwich         0  ...
# 6601                   19        West Ham         0  ...
# 14284                  15   Sheffield Utd         0  ...
# 13735                   3     Bournemouth         0  ...
# 16452                   9       Leicester         0  ...
# 4435                   11        Man City         0  ...
# 3679                   19        West Ham         0  ...
# 7355                    1         Arsenal         0  ...
# 9333                    2     Aston Villa         0  ...
#
#        LSS_df_avg_influence  LSS_df_avg_threat  \
# 1647              16.394737           6.657895
# 16064             19.105263           9.105263
# 13282              3.889474           6.000000
# 13382              8.534921           6.960317
# 7340              17.547368          12.815789
# 13328             27.894737          41.368421
# 4921               8.534921           6.960317
# 2194               9.631579           9.921053
# 681                0.268421           0.500000
# 5106               6.942105          11.605263
# 5063               9.563158           3.184211
# 15465              2.563158           1.052632
# 13776             12.126316          10.000000
# 6161               3.147368           1.342105
# 3614              10.542105           5.710526
# 5803               8.534921           6.960317
# 13483              0.000000           0.000000
# 12193              0.936842           0.815789
# 354                5.878947           6.973684
# 3127              23.052632          21.078947
# 9820              18.863158          27.342105
# 11835              3.989474           0.447368
# 10655              8.534921           6.960317
# 10685             13.721053           5.157895
# 412                3.457895           5.552632
# 12991             13.952632          19.289474
# 6276               8.534921           6.960317
# 6729               8.534921           6.960317
# 13225             16.210526          11.078947
# 2591               8.534921           6.960317
# ...                     ...                ...
# 1216               8.534921           6.960317
# 14236             18.373684          10.578947
# 14136             24.489474          18.315789
# 1469               8.534921           6.960317
# 8635               0.050000           1.150000
# 13488              0.000000           0.000000
# 13270              3.889474           6.000000
# 680                0.268421           0.500000
# 10206              8.534921           6.960317
# 7386              15.452632           9.842105
# 1120              19.552632          16.368421
# 11877              8.534921           6.960317
# 12866             28.863158          32.789474
# 15548              8.534921           6.960317
# 7813              14.200000           4.578947
# 7065               1.410526           0.578947
# 14558              3.622222           2.944444
# 1809              20.621053          25.105263
# 13146             13.015789           9.868421
# 2078               8.534921           6.960317
# 10481              8.534921           6.960317
# 15263              8.534921           6.960317
# 6601              16.557895           4.421053
# 14284             26.731579          35.052632
# 13735              5.600000           7.815789
# 16452              6.668421           5.289474
# 4435               8.534921           6.960317
# 3679               8.534921           6.960317
# 7355               0.136842           0.000000
# 9333               7.931579           8.342105
#
#        LSS_df_avg_GK_DEF_MID_clean_sheets  LSS_df_avg_selected_by  \
# 1647                             0.184211            1.331667e+05
# 16064                            0.236842            4.781895e+04
# 13282                            0.026316            8.967132e+03
# 13382                            0.146825            1.081968e+05
# 7340                             0.289474            1.275433e+05
# 13328                            0.447368            8.050246e+05
# 4921                             0.146825            1.081968e+05
# 2194                             0.342105            1.399687e+04
# 681                              0.000000            2.305737e+03
# 5106                             0.105263            3.099784e+04
# 5063                             0.131579            7.987371e+04
# 15465                            0.078947            1.030079e+03
# 13776                            0.131579            6.683308e+04
# 6161                             0.105263            7.101763e+03
# 3614                             0.105263            5.422263e+03
# 5803                             0.146825            1.081968e+05
# 13483                            0.000000            2.709455e+04
# 12193                            0.000000            7.430632e+03
# 354                              0.026316            2.108734e+04
# 3127                             0.210526            4.191670e+05
# 9820                             0.236842            5.868422e+05
# 11835                            0.131579            1.132841e+05
# 10655                            0.146825            1.081968e+05
# 10685                            0.184211            2.085695e+04
# 412                              0.026316            6.714789e+03
# 12991                            0.184211            2.996761e+05
# 6276                             0.146825            1.081968e+05
# 6729                             0.146825            1.081968e+05
# 13225                            0.105263            1.841243e+05
# 2591                             0.146825            1.081968e+05
# ...                                   ...                     ...
# 1216                             0.146825            1.081968e+05
# 14236                            0.210526            8.579722e+05
# 14136                            0.236842            1.236993e+06
# 1469                             0.146825            1.081968e+05
# 8635                             0.050000            2.627000e+02
# 13488                            0.000000            2.709455e+04
# 13270                            0.026316            8.967132e+03
# 680                              0.000000            2.305737e+03
# 10206                            0.146825            1.081968e+05
# 7386                             0.236842            2.083559e+05
# 1120                             0.289474            1.555466e+05
# 11877                            0.146825            1.081968e+05
# 12866                            0.210526            1.542725e+06
# 15548                            0.146825            1.081968e+05
# 7813                             0.236842            1.860971e+04
# 7065                             0.026316            2.492579e+03
# 14558                            0.083333            2.349889e+03
# 1809                             0.289474            8.699074e+04
# 13146                            0.131579            9.863371e+04
# 2078                             0.146825            1.081968e+05
# 10481                            0.146825            1.081968e+05
# 15263                            0.146825            1.081968e+05
# 6601                             0.342105            1.893750e+04
# 14284                            0.500000            1.735298e+06
# 13735                            0.157895            6.003855e+04
# 16452                            0.078947            1.702974e+03
# 4435                             0.146825            1.081968e+05
# 3679                             0.146825            1.081968e+05
# 7355                             0.000000            2.026947e+03
# 9333                             0.157895            2.738347e+05
#
#        LSS_df_avg_cost  LSS_df_no_player_history  TARGET_minutes  \
# 1647         45.342105                       0.0            90.0
# 16064        49.131579                       0.0            90.0
# 13282        51.368421                       0.0             0.0
# 13382        55.670635                       1.0             0.0
# 7340         48.157895                       0.0            90.0
# 13328       113.289474                       0.0            90.0
# 4921         55.670635                       1.0             0.0
# 2194         59.105263                       0.0             0.0
# 681          64.131579                       0.0            83.0
# 5106         61.894737                       0.0             0.0
# 5063         47.736842                       0.0             0.0
# 15465        50.000000                       0.0             0.0
# 13776        52.315789                       0.0            83.0
# 6161         43.368421                       0.0             0.0
# 3614         48.026316                       0.0            16.0
# 5803         55.670635                       1.0             0.0
# 13483        44.078947                       0.0            28.0
# 12193        44.552632                       0.0             1.0
# 354          52.631579                       0.0            90.0
# 3127         92.947368                       0.0            45.0
# 9820         94.078947                       0.0             0.0
# 11835        42.973684                       0.0            80.0
# 10655        55.670635                       1.0             0.0
# 10685        48.578947                       0.0            90.0
# 412          51.000000                       0.0             0.0
# 12991        63.736842                       0.0             0.0
# 6276         55.670635                       1.0            74.0
# 6729         55.670635                       1.0            13.0
# 13225        44.315789                       0.0            90.0
# 2591         55.670635                       1.0             0.0
# ...                ...                       ...             ...
# 1216         55.670635                       1.0             0.0
# 14236        49.868421                       0.0            90.0
# 14136        60.763158                       0.0            90.0
# 1469         55.670635                       1.0            69.0
# 8635         45.000000                       0.0            69.0
# 13488        44.078947                       0.0             0.0
# 13270        51.368421                       0.0             0.0
# 680          64.131579                       0.0            64.0
# 10206        55.670635                       1.0             0.0
# 7386         56.052632                       0.0            29.0
# 1120         58.000000                       0.0             9.0
# 11877        55.670635                       1.0             0.0
# 12866        83.473684                       0.0             0.0
# 15548        55.670635                       1.0            45.0
# 7813         45.000000                       0.0            90.0
# 7065         47.815789                       0.0             0.0
# 14558        45.000000                       0.0             5.0
# 1809         61.526316                       0.0            18.0
# 13146        45.000000                       0.0            90.0
# 2078         55.670635                       1.0            45.0
# 10481        55.670635                       1.0             0.0
# 15263        55.670635                       1.0             0.0
# 6601         48.000000                       0.0             0.0
# 14284        97.921053                       0.0            90.0
# 13735        48.421053                       0.0             0.0
# 16452        47.131579                       0.0            13.0
# 4435         55.670635                       1.0            84.0
# 3679         55.670635                       1.0             0.0
# 7355         44.157895                       0.0             1.0
# 9333         97.184211                       0.0            62.0
#
#        TARGET_total_points  TARGET_total_points_BIN_EVEN  \
# 1647                   5.0                           3.0
# 16064                  3.0                           2.0
# 13282                  0.0                           1.0
# 13382                  0.0                           1.0
# 7340                   2.0                           2.0
# 13328                  5.0                           3.0
# 4921                   0.0                           1.0
# 2194                   0.0                           1.0
# 681                    2.0                           2.0
# 5106                   0.0                           1.0
# 5063                   0.0                           1.0
# 15465                  0.0                           1.0
# 13776                  5.0                           3.0
# 6161                   0.0                           1.0
# 3614                   1.0                           2.0
# 5803                   0.0                           1.0
# 13483                  1.0                           2.0
# 12193                  1.0                           2.0
# 354                    8.0                           4.0
# 3127                   1.0                           2.0
# 9820                   0.0                           1.0
# 11835                  1.0                           2.0
# 10655                  0.0                           1.0
# 10685                  2.0                           2.0
# 412                    0.0                           1.0
# 12991                  0.0                           1.0
# 6276                   2.0                           2.0
# 6729                   1.0                           2.0
# 13225                  1.0                           2.0
# 2591                   0.0                           1.0
# ...                    ...                           ...
# 1216                   0.0                           1.0
# 14236                  2.0                           2.0
# 14136                  2.0                           2.0
# 1469                   7.0                           4.0
# 8635                   2.0                           2.0
# 13488                  0.0                           1.0
# 13270                  0.0                           1.0
# 680                    2.0                           2.0
# 10206                  0.0                           1.0
# 7386                   1.0                           2.0
# 1120                   1.0                           2.0
# 11877                  0.0                           1.0
# 12866                  0.0                           1.0
# 15548                  1.0                           2.0
# 7813                   1.0                           2.0
# 7065                   0.0                           1.0
# 14558                  4.0                           3.0
# 1809                   1.0                           2.0
# 13146                  2.0                           2.0
# 2078                   1.0                           2.0
# 10481                  0.0                           1.0
# 15263                  0.0                           1.0
# 6601                   0.0                           1.0
# 14284                  3.0                           2.0
# 13735                  0.0                           1.0
# 16452                  1.0                           2.0
# 4435                   2.0                           2.0
# 3679                   0.0                           1.0
# 7355                   1.0                           2.0
# 9333                   9.0                           4.0
#
#        TARGET_total_points_BIN_QUAR
# 1647                            3.0
# 16064                           3.0
# 13282                           0.0
# 13382                           0.0
# 7340                            2.0
# 13328                           3.0
# 4921                            0.0
# 2194                            0.0
# 681                             2.0
# 5106                            0.0
# 5063                            0.0
# 15465                           0.0
# 13776                           3.0
# 6161                            0.0
# 3614                            1.0
# 5803                            0.0
# 13483                           1.0
# 12193                           1.0
# 354                             4.0
# 3127                            1.0
# 9820                            0.0
# 11835                           1.0
# 10655                           0.0
# 10685                           2.0
# 412                             0.0
# 12991                           0.0
# 6276                            2.0
# 6729                            1.0
# 13225                           1.0
# 2591                            0.0
# ...                             ...
# 1216                            0.0
# 14236                           2.0
# 14136                           2.0
# 1469                            4.0
# 8635                            2.0
# 13488                           0.0
# 13270                           0.0
# 680                             2.0
# 10206                           0.0
# 7386                            1.0
# 1120                            1.0
# 11877                           0.0
# 12866                           0.0
# 15548                           1.0
# 7813                            1.0
# 7065                            0.0
# 14558                           3.0
# 1809                            1.0
# 13146                           2.0
# 2078                            1.0
# 10481                           0.0
# 15263                           0.0
# 6601                            0.0
# 14284                           3.0
# 13735                           0.0
# 16452                           1.0
# 4435                            2.0
# 3679                            0.0
# 7355                            1.0
# 9333                            4.0
#
# [1894 rows x 96 columns]

# %%
evaluation = evaluate_set.groupby('PLAYER_name')[['prediction','TARGET_total_points']].sum()
evaluation.head()
# Out:
#                         prediction  TARGET_total_points
# PLAYER_name
# Aaron_Lennon_430          2.949582                  1.0
# Aaron_Mooy_516           13.536077                 21.0
# Abdoulaye_Doucouré_368   32.910936                 28.0
# Adam_Lallana_195          9.365847                 12.0
# Adama_Traoré_417         37.510589                 52.0

# %%
evaluation.columns
# Out:
# Index(['prediction', 'TARGET_total_points'], dtype='object')

# %%
plot_results(evaluation['TARGET_total_points'],evaluation['prediction'])
# Out:
# R2:  0.21877107666719497

# %%
evaluation['prediction_rank'] = evaluation['prediction'].rank()
evaluation['actual_rank'] = evaluation['TARGET_total_points'].rank()

# %%
evaluation.sort_values('prediction', ascending = False)
# Out:
#                             prediction  TARGET_total_points  prediction_rank  \
# PLAYER_name
# Mohamed_Salah_191            46.591688                 70.0            251.0
# Kevin_De Bruyne_215          45.450752                 51.0            250.0
# Pierre-Emile_Højbjerg_325    40.965137                 29.0            249.0
# Mason_Mount_463              37.841659                 24.0            248.0
# Adama_Traoré_417             37.510589                 52.0            247.0
# Leander_Dendoncker_420       35.147884                 19.0            246.0
# Nicolas_Pépé_488             35.040649                 26.0            245.0
# Bamidele_Alli_344            35.023647                 42.0            244.0
# Wilfried_Zaha_133            34.423950                 24.0            243.0
# Sadio_Mané_192               33.589586                 43.0            242.0
# James_Maddison_171           33.009528                 43.0            241.0
# Abdoulaye_Doucouré_368       32.910936                 28.0            240.0
# Ayoze_Pérez_265              32.014090                 47.0            239.0
# Gylfi_Sigurdsson_151         31.865651                 20.0            238.0
# Jack_Grealish_29             31.682042                 29.0            237.0
# Davy_Pröpper_54              31.480974                 22.0            236.0
# Miguel_Almirón_266           31.050677                 34.0            235.0
# Dwight_McNeil_97             31.029670                 43.0            234.0
# Anthony_Martial_239          30.456254                 42.0            233.0
# Jordan_Henderson_198         30.148701                 33.0            232.0
# Jack_Cork_102                30.088239                 23.0            231.0
# Pascal_Groß_49               29.128317                 26.0            230.0
# Ryan_Fraser_75               28.994593                 18.0            229.0
# Nathan_Redmond_320           28.212939                 22.0            228.0
# Anwar_El Ghazi_30            26.673224                 26.0            227.0
# Allan_Saint-Maximin_500      26.445706                 23.0            226.0
# David_Silva_219              26.089304                  4.0            225.0
# Raheem_Sterling_214          25.823145                 33.0            224.0
# Ashley_Westwood_101          25.693112                 30.0            223.0
# Youri_Tielemans_448          24.938487                 30.0            222.0
# ...                                ...                  ...              ...
# Thomas_Allan_598             -0.034710                  0.0             30.0
# Ethan_Ampadu_121             -0.063269                  0.0             29.0
# Christian_Saydee_564         -0.064975                  0.0             28.0
# Owen_Otasowie_566            -0.130982                  0.0             27.0
# Valentino_Lazaro_614         -0.138789                  1.0             26.0
# Daniel_Drinkwater_120        -0.139169                  0.0             25.0
# Ken_Sema_372                 -0.142066                  0.0             24.0
# Matty_James_177              -0.154910                  1.0             23.0
# Grady_Diangana_398           -0.225262                  0.0             22.0
# Ayotomiwa_Dele-Bashiru_563   -0.264094                  0.0             21.0
# William_Smallbone_584        -0.276896                  0.0             20.0
# Luke_Cundle_567              -0.303585                  0.0             19.0
# Tyreke_Johnson_326           -0.330469                  0.0             18.0
# Daniel_Amartey_178           -0.352717                  0.0             17.0
# Luke_Amos_351                -0.435586                  0.0             16.0
# Mihai-Alexandru_Dobre_574    -0.445055                  0.0             15.0
# Birkir_Bjarnason_33          -0.501930                  0.0             14.0
# Jacob_Murphy_483             -0.542861                  0.0             13.0
# Callum_Slattery_327          -0.608749                  0.0             12.0
# Jack_Colback_482             -0.692634                  0.0             11.0
# Ademola_Lookman_155          -0.694631                  0.0             10.0
# Bernardo_Costa Da Rosa_595   -0.728713                  0.0              9.0
# Ivan_Cavaleiro_419           -0.864530                  0.0              8.0
# Mario_Lemina_324             -0.937004                  0.0              7.0
# James_Garner_250             -1.135145                  0.0              6.0
# Beni_Baningime_557           -1.357600                  0.0              5.0
# Domingos_Quina_375           -1.391419                  1.0              4.0
# Luke_Dreher_140              -1.634502                  0.0              3.0
# Pedro_Obiang_400             -2.166876                  0.0              2.0
# Beram_Kayal_56               -2.344553                  0.0              1.0
#
#                             actual_rank
# PLAYER_name
# Mohamed_Salah_191                 251.0
# Kevin_De Bruyne_215               249.0
# Pierre-Emile_Højbjerg_325         232.0
# Mason_Mount_463                   216.0
# Adama_Traoré_417                  250.0
# Leander_Dendoncker_420            190.5
# Nicolas_Pépé_488                  222.5
# Bamidele_Alli_344                 243.5
# Wilfried_Zaha_133                 216.0
# Sadio_Mané_192                    246.0
# James_Maddison_171                246.0
# Abdoulaye_Doucouré_368            229.0
# Ayoze_Pérez_265                   248.0
# Gylfi_Sigurdsson_151              195.5
# Jack_Grealish_29                  232.0
# Davy_Pröpper_54                   206.0
# Miguel_Almirón_266                241.5
# Dwight_McNeil_97                  246.0
# Anthony_Martial_239               243.5
# Jordan_Henderson_198              239.5
# Jack_Cork_102                     211.0
# Pascal_Groß_49                    222.5
# Ryan_Fraser_75                    186.5
# Nathan_Redmond_320                206.0
# Anwar_El Ghazi_30                 222.5
# Allan_Saint-Maximin_500           211.0
# David_Silva_219                   106.0
# Raheem_Sterling_214               239.5
# Ashley_Westwood_101               235.5
# Youri_Tielemans_448               235.5
# ...                                 ...
# Thomas_Allan_598                   35.5
# Ethan_Ampadu_121                   35.5
# Christian_Saydee_564               35.5
# Owen_Otasowie_566                  35.5
# Valentino_Lazaro_614               79.5
# Daniel_Drinkwater_120              35.5
# Ken_Sema_372                       35.5
# Matty_James_177                    79.5
# Grady_Diangana_398                 35.5
# Ayotomiwa_Dele-Bashiru_563         35.5
# William_Smallbone_584              35.5
# Luke_Cundle_567                    35.5
# Tyreke_Johnson_326                 35.5
# Daniel_Amartey_178                 35.5
# Luke_Amos_351                      35.5
# Mihai-Alexandru_Dobre_574          35.5
# Birkir_Bjarnason_33                35.5
# Jacob_Murphy_483                   35.5
# Callum_Slattery_327                35.5
# Jack_Colback_482                   35.5
# Ademola_Lookman_155                35.5
# Bernardo_Costa Da Rosa_595         35.5
# Ivan_Cavaleiro_419                 35.5
# Mario_Lemina_324                   35.5
# James_Garner_250                   35.5
# Beni_Baningime_557                 35.5
# Domingos_Quina_375                 79.5
# Luke_Dreher_140                    35.5
# Pedro_Obiang_400                   35.5
# Beram_Kayal_56                     35.5
#
# [251 rows x 4 columns]

# %% [markdown]
# ## KNN

# %% [markdown]
# ## SVM

# %% [markdown]
# ## LASSO regression

# %%
# Compute correlations
cor = historic_df_MID.corr()

#Correlation with output variable
cor_target = abs(cor["TARGET_total_points"])
cor_target.drop(index = [c for c in cor_target.index if str.startswith(c, ('TARGET'))], inplace = True)

cor_target.sort_values(ascending = False)

relevant_features = cor_target[cor_target>0.4]
relevant_features
# Out:
# LW_minutes_played         0.445187
# L4W_avg_total_points      0.440366
# L4W_avg_minutes_played    0.450197
# L4W_avg_creativity        0.408141
# L4W_avg_influence         0.427217
# L4W_avg_threat            0.410819
# TSS_avg_total_points      0.468907
# TSS_stdev_total_points    0.418618
# TSS_avg_minutes_played    0.431957
# TSS_avg_creativity        0.407434
# TSS_avg_influence         0.449678
# TSS_stdev_influence       0.426931
# TSS_avg_threat            0.414008
# TSS_stdev_threat          0.400120
# Name: TARGET_total_points, dtype: float64

# %%
X = historic_df_MID[relevant_features.index.values].drop(columns = 'TSS_avg_total_points')
y = historic_df_MID['TARGET_total_points']

# Create test and training dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

regressor = Lasso() 
regressor.fit(X_train,y_train)
fit = regressor.predict(X_test) 

plot_results(y_test,fit)
# Out:
# R2:  0.23378075473391946

# %% [markdown]
# ## LightGBM
