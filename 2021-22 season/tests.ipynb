# %%
import pandas as pd
import requests
import json

# %% [markdown]
# # Bootstrap response

# %%
bootstrap_API_response = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/').json()

# %%
GWs_API_load_df = pd.DataFrame.from_dict(bootstrap_API_response['events'])
GWs_API_load_df
# Out:
#     id         name         deadline_time  average_entry_score  finished  \
# 0    1   Gameweek 1  2021-08-13T17:30:00Z                   69      True
# 1    2   Gameweek 2  2021-08-21T10:00:00Z                   45     False
# 2    3   Gameweek 3  2021-08-28T10:00:00Z                    0     False
# 3    4   Gameweek 4  2021-09-11T10:00:00Z                    0     False
# 4    5   Gameweek 5  2021-09-17T17:30:00Z                    0     False
# 5    6   Gameweek 6  2021-09-25T10:00:00Z                    0     False
# 6    7   Gameweek 7  2021-10-02T10:00:00Z                    0     False
# 7    8   Gameweek 8  2021-10-16T10:00:00Z                    0     False
# 8    9   Gameweek 9  2021-10-22T17:30:00Z                    0     False
# 9   10  Gameweek 10  2021-10-30T10:00:00Z                    0     False
# 10  11  Gameweek 11  2021-11-06T13:30:00Z                    0     False
# 11  12  Gameweek 12  2021-11-20T13:30:00Z                    0     False
# ...

# %%
teams_API_load_df = pd.DataFrame.from_dict(bootstrap_API_response['teams'])
teams_API_load_df.head()
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         0
# 1     7     0  None   2     0  Aston Villa       0       0         0
# 2    94     0  None   3     0    Brentford       0       0         0
# 3    36     0  None   4     0     Brighton       0       0         0
# 4    90     0  None   5     0      Burnley       0       0         0
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1200
# 1        AVL  ...           None       False    0                   1100
# 2        BRE  ...           None       False    0                   1010
# 3        BHA  ...           None       False    0                   1100
# 4        BUR  ...           None       False    0                   1060
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# ...

# %%
elements_API_load_df = pd.DataFrame.from_dict(bootstrap_API_response['elements'])
elements_API_load_df
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                             NaN                           NaN   80201
# 1                             0.0                           0.0  115918
# 2                            50.0                          50.0   47431
# 3                           100.0                          50.0   54694
# 4                             NaN                           NaN   58822
# ..                            ...                           ...     ...
# 561                           NaN                           NaN  149065
# 562                           0.0                           0.0  209353
# 563                           NaN                           NaN  245923
# 564                           NaN                           NaN  461026
# 565                           NaN                           NaN  481626
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# ...

# %%
elements_API_load_df[['first_name',
                      'second_name',
                      'id',
                      'chance_of_playing_next_round',
                      'element_type',
                      'news',
                      'now_cost',
                      'status',
                      'team']]

# %%
elements_API_load_df

# %%
positions_API_load_df = pd.DataFrame.from_dict(bootstrap_API_response['element_types'])
positions_API_load_df
# Out:
#    id  plural_name plural_name_short singular_name singular_name_short  \
# 0   1  Goalkeepers               GKP    Goalkeeper                 GKP
# 1   2    Defenders               DEF      Defender                 DEF
# 2   3  Midfielders               MID    Midfielder                 MID
# 3   4     Forwards               FWD       Forward                 FWD
#
#    squad_select  squad_min_play  squad_max_play  ui_shirt_specific  \
# 0             2               1               1               True
# 1             5               3               5              False
# 2             5               2               5              False
# 3             3               1               3              False
#
#   sub_positions_locked  element_count
# 0                 [12]             60
# 1                   []            194
# 2                   []            236
# 3                   []             76

# %% [markdown]
# # Fixtures response

# %%
fixtures_API_response = requests.get('https://fantasy.premierleague.com/api/fixtures/').json()
fixtures_API_load_df = pd.DataFrame.from_dict(fixtures_API_response)
fixtures_API_load_df.head()
# Out:
#       code  event  finished  finished_provisional  id          kickoff_time  \
# 0  2210271      1      True                  True   1  2021-08-13T19:00:00Z
# 1  2210276      1      True                  True   6  2021-08-14T11:30:00Z
# 2  2210272      1      True                  True   2  2021-08-14T14:00:00Z
# 3  2210273      1      True                  True   3  2021-08-14T14:00:00Z
# 4  2210274      1      True                  True   4  2021-08-14T14:00:00Z
#
#    minutes  provisional_start_time  started  team_a  team_a_score  team_h  \
# 0       90                   False     True       1           0.0       3
# 1       90                   False     True      10           1.0      13
# 2       90                   False     True       4           2.0       5
# 3       90                   False     True       7           0.0       6
# 4       90                   False     True      16           1.0       8
#
# ...

# %%
fixtures_API_load_df[['event',
                      'kickoff_time',
                      'team_a',
                      'team_h',]]
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2210271      1      True                  True    1
# 1    2210276      1      True                  True    6
# 2    2210272      1      True                  True    2
# 3    2210273      1      True                  True    3
# 4    2210274      1      True                  True    4
# ..       ...    ...       ...                   ...  ...
# 375  2210646     38     False                 False  376
# 376  2210647     38     False                 False  377
# 377  2210648     38     False                 False  378
# 378  2210649     38     False                 False  379
# 379  2210650     38     False                 False  380
#
#              kickoff_time  minutes  provisional_start_time  started  team_a  \
# 0    2021-08-13T19:00:00Z       90                   False     True       1
# 1    2021-08-14T11:30:00Z       90                   False     True      10
# ...

# %% [markdown]
# # Matches data

# %%
matches_API_response = requests.get('https://fantasy.premierleague.com/api/element-summary/43/').json()

upcoming_matches = pd.DataFrame.from_dict(matches_API_response['fixtures'])
upcoming_matches
# Out:
#      id     code  team_h team_h_score  team_a team_a_score  event  finished  \
# 0    21  2210291       2         None       3         None      3     False
# 1    33  2210303       6         None       2         None      4     False
# 2    41  2210311       2         None       8         None      5     False
# 3    58  2210328      13         None       2         None      6     False
# 4    68  2210338      17         None       2         None      7     False
# 5    72  2210342       2         None      20         None      8     False
# 6    81  2210351       1         None       2         None      9     False
# 7    91  2210361       2         None      19         None     10     False
# 8   109  2210379      16         None       2         None     11     False
# 9   111  2210381       2         None       4         None     12     False
# 10  126  2210396       7         None       2         None     13     False
# ...

# %%
previous_matches = pd.DataFrame.from_dict(matches_API_response['history'])
previous_matches
# Out:
#    element  fixture  opponent_team  total_points  was_home  \
# 0       43        8             18             2     False
# 1       43       11             14             2      True
#
#            kickoff_time  team_h_score  team_a_score  round  minutes  ...  bps  \
# 0  2021-08-14T14:00:00Z             3             2      1       71  ...    6
# 1  2021-08-21T14:00:00Z             2             0      2       85  ...    6
#
#    influence  creativity  threat  ict_index  value  transfers_balance  \
# 0        4.2         5.3    10.0        2.0     65                  0
# 1       11.6        36.2     2.0        5.0     65             -31772
#
#    selected  transfers_in  transfers_out
# 0    386824             0              0
# 1    374696         20786          52558
#
# [2 rows x 31 columns]

# %%
matches_API_response = requests.get('https://fantasy.premierleague.com/api/element-summary/81/').json()
pd.DataFrame.from_dict(matches_API_response['history_past'])
# Out:
#   season_name  element_code  start_cost  end_cost  total_points  minutes  \
# 0     2015/16        174932          45        45             1       10
#
#    goals_scored  assists  clean_sheets  goals_conceded  ...  penalties_missed  \
# 0             0        0             0               0  ...                 0
#
#    yellow_cards  red_cards  saves  bonus  bps  influence  creativity threat  \
# 0             0          0      0      0    2        0.0         0.0    0.0
#
#   ict_index
# 0       0.0
#
# [1 rows x 22 columns]
